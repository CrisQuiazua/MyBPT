# %% [markdown]
# ## Objetivo:
# Según el Crossmatching de SDSS e IRAS (2. Cruce entre SDSS e IRAS.ipynb) (Tabla fusionada con 1.269 elementos SSDS Vs IRAS)
# CRUCE TOTAL y Datos ETIQUETADO 100%: CON 500.000 OBJETOS (4.2 Etiqueta Total 3GRUPOS, CON PORCENTAJES).
#
#     Datos de entrada:
#     Infrarroja 245.957
#     Seyfert 16.473
#     LINER 77
#
# Total: 262.501 que son el 84.60% de los datos iniciales (310.346).
#
# Operaciones:
#     * Completar las operaciones que hacen falta para realizar las gráficas según (1.1 Graficas con LOG sencillas y con LOG en razones).
#     * Realizar las gráficas de 1.1 Graficas con LOG sencillas y con LOG en razones.
#     * Realizar las gráficas según identificador de acuerdo a la columna de etiqueta de referencia "EtiqRef"
#     Gráficas de:
#     Log 12 Vs Log 60
#      Log_12_25 / Log_12_60

# %%
# Importando Cruce entre SDSS e IRAS
# %run "C:\Users\Cristina Quiazúa M\Desktop\MyBPT\Crossmatching\2. Cruce entre SDSS e IRAS.ipynb"
# Out:
# Could not import regions, which is required for some of the functionalities of this module.
# Valores duplicados en la columna 'ra': [132.58559 179.51375 185.48906 351.8132 ]
# Índices de los valores duplicados en la columna 'ra': Int64Index([4105, 5929, 6215, 11228], dtype='int64')
# Índices de TODAS las ocurrencias de valores duplicados en la columna 'ra': Int64Index([4100, 4105, 5928, 5929, 6213, 6215, 11227, 11228], dtype='int64')
# C:\ProgramData\Anaconda33\lib\site-packages\astroquery\sdss\core.py:874: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   arr = np.atleast_1d(np.genfromtxt(io.BytesIO(response.content),
# Número de valores únicos: 293697
# Número de valores repetidos 1 vez: 14895
# Número de valores repetidos 2 veces: 1239
# Número de valores repetidos 3 veces: 211
# Número de valores repetidos 4 veces: 242
# Número de valores repetidos 5 veces: 45
# ...

# %%
# Importando 4.3 Etiquetado 100% con 500.000 Galaxias.
# %run "C:\Users\Cristina Quiazúa M\Desktop\MyBPT\SDSS\With500MD\4.2 Etiqueta Total 3GRUPOS, CON PORCENTAJES.ipynb"
# Out:
# Valores duplicados en la columna 'ra': [132.58559 179.51375 185.48906 351.8132 ]
# Índices de los valores duplicados en la columna 'ra': Int64Index([4105, 5929, 6215, 11228], dtype='int64')
# Índices de TODAS las ocurrencias de valores duplicados en la columna 'ra': Int64Index([4100, 4105, 5928, 5929, 6213, 6215, 11227, 11228], dtype='int64')
# C:\ProgramData\Anaconda33\lib\site-packages\astroquery\sdss\core.py:874: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   arr = np.atleast_1d(np.genfromtxt(io.BytesIO(response.content),
# Número de valores únicos: 293697
# Número de valores repetidos 1 vez: 14895
# Número de valores repetidos 2 veces: 1239
# Número de valores repetidos 3 veces: 211
# Número de valores repetidos 4 veces: 242
# Número de valores repetidos 5 veces: 45
# Número de valores repetidos 6 veces: 14
# Número de valores repetidos 7 veces: 3
# ...

# %%
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss     ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.513947  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.234604  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.707565  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.826675 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.385590 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...      class  \
# 0      153.8173     35.59267        3.656026       13.19764  ...  b'GALAXY'
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...  b'GALAXY'
# 2      528.2295    139.90980       34.019120       62.50361  ...  b'GALAXY'
# 3      998.6539    263.62670      358.444700       54.00912  ...  b'GALAXY'
# 4      520.6220     74.79313       28.152840       74.78139  ...  b'GALAXY'
#
# ...

# %%
len(FusionData)
# Out:
# 1269

# %%
Coin100[0:5]
# Out:
#             specobjid         ra       dec         z  h_alpha_flux  \
# 0  299489677444933632  146.71421 -1.041304  0.021222      472.5904
# 2  299491051364706304  146.96390 -0.545003  0.055988      181.5262
# 3  299491051834468352  146.63167 -0.988278  0.052654      127.3058
# 4  299492700632147968  146.59272 -0.760256  0.065024      211.5018
# 5  299493250857723904  146.94999 -0.592202  0.064779      229.1325
#
#    h_beta_flux  oiii_5007_flux  nii_6548_flux  nii_6584_flux  sii_6717_flux  \
# 0    119.49560        68.39606      74.302520      224.11360      124.71150
# 2     47.36650        11.85567      17.948720       54.13749       31.28298
# 3     38.33226        35.46671       8.550285       25.78963       30.26996
# 4     53.18228        15.59901      25.314650       76.35482       41.63770
# 5     60.80691        29.73346      24.491550       73.87218       45.46917
#
#    sii_6731_flux  oi_6300_flux        subclass  Ejey_OHB   Ejex_NH   Ejex_SH  \
# ...

# %%
# Cambiando nombre del df Coin100 a dfref
dfref = Coin100

# %%
# Cambiando nombre de columna "Coin100%" a dfref
dfref.rename(columns={'Coin100%': 'EtiqRef'}, inplace=True)

# %%
len(dfref)
# Out:
# 262501

# %% [markdown]
# ## Union de tablas dados ra_sdss	dec_sdss y ra y dec.

# %%
data = pd.merge(FusionData, dfref[['ra', 'dec', 'EtiqRef']], left_on=['ra_sdss', 'dec_sdss'], right_on=['ra', 'dec'], how='left')

# %%
data[24:30]
# Out:
#       ra_sdss  dec_sdss     ra_iras  dec_iras           specobjid         z  \
# 24  220.23482 -0.318170  220.235550 -0.318815  345669990998894592  0.005755
# 25  219.46892 -0.398629  219.470779 -0.399236  345702151714007040  0.006428
# 26  221.54637 -0.222966  221.546524 -0.224672  346829700871514112  0.005535
# 27  231.65696  0.592640  231.657318  0.593575  352546336886777856  0.050691
# 28  235.49810  0.712802  235.497986  0.712695  354807207503620096  0.006395
# 29  170.89667 -1.565725  170.897415 -1.566871  367134668941715456  0.044631
#
#     h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  fnu_12  \
# 24     3314.8680    507.80840       244.87300      687.72990  ...    0.57
# 25     2653.3270    586.72450       459.61690      186.05010  ...    0.25
# 26      803.5585    216.12770       345.87280      282.88700  ...    0.25
# 27     1509.2250    304.37040      2897.91300      394.63270  ...    0.25
# ...

# %%
len(data) #Total de datos que se cruzan, pueden ser mas si no restrinjo en 4.2 de SDSS las infrarrojaS.
# Out:
# 1269

# %%
# Removiendo los datos que tengan en EtiqRef NaN
data = data.dropna(subset=['EtiqRef'])

# %%
data[0:3]
# Out:
#      ra_sdss  dec_sdss     ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.513947  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.234604  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.707565  0.617749  314283887213701120  0.025391
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  fnu_12  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    0.35
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...    0.42
# 2      528.2295    139.90980       34.019120       62.50361  ...    0.25
#
#    fnu_25  fnu_60  fnu_100 rat_12_25 rat_25_60 rat_60_100         ra  \
# 0    0.50    5.16    15.08  0.700000  0.096899   0.342175  145.51241
# 1    0.27    0.82     1.01  1.555556  0.329268   0.811881  167.23240
# 2    0.50    0.75     1.79  0.500000  0.666667   0.418994  169.70646
#
#         dec     EtiqRef
# 0  0.339171  Infrarroja
# 1  0.444804  Infrarroja
# ...

# %%
len(data) ## Hay 156
# Out:
# 1023

# %%
# Cuantos infrarrojas, Seyfert y LINER fueron clasificadas:
conteo = data['EtiqRef'].value_counts()
conteo
# Out:
# Infrarroja    963
# Seyfert        60
# Name: EtiqRef, dtype: int64

# %%
data.columns
# Out:
# Index(['ra_sdss', 'dec_sdss', 'ra_iras', 'dec_iras', 'specobjid', 'z',
#        'h_alpha_flux', 'h_beta_flux', 'oiii_5007_flux', 'nii_6548_flux',
#        'nii_6584_flux', 'sii_6717_flux', 'sii_6731_flux', 'oi_6300_flux',
#        'class', 'subclass', 'galname', 'fnu_12', 'fnu_25', 'fnu_60', 'fnu_100',
#        'rat_12_25', 'rat_25_60', 'rat_60_100', 'ra', 'dec', 'EtiqRef'],
#       dtype='object')

# %%
# Razones que faltan
rat_12_60 = data['fnu_12']/data['fnu_60']
rat_12_100 = data['fnu_12']/data['fnu_100']
rat_25_100 = data['fnu_25']/data['fnu_100']

# %%
# Ingresar a la tabla:
data["rat_12_60"]= rat_12_60
data["rat_12_100"]= rat_12_100
data["rat_25_100"]= rat_25_100

# %%
data
# Out:
#         ra_sdss   dec_sdss     ra_iras   dec_iras            specobjid  \
# 0     145.51241   0.339171  145.513947   0.337522   299595780317014016
# 1     167.23240   0.444804  167.234604   0.444661   313129123717343232
# 2     169.70646   0.619308  169.707565   0.617749   314283887213701120
# 3     170.82587  -0.922475  170.826675  -0.921258   315274540949202944
# 4     169.38707  -0.187502  169.385590  -0.186404   315334739210823680
# ...         ...        ...         ...        ...                  ...
# 1263  233.51610   2.210490  233.515137   2.211006  3326065631496792064
# 1264  236.56954   2.414467  236.566910   2.415057  3327201701902968832
# 1266  242.24222  19.823751  242.241013  19.822510  3340714425299527680
# 1267  245.78193  19.004866  245.783188  19.005993  3344057765365573632
# 1268  258.72922  35.520481  258.729187  35.520664  3346347498280085504
#
#              z  h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  \
# ...

# %%
data.columns
# Out:
# Index(['ra_sdss', 'dec_sdss', 'ra_iras', 'dec_iras', 'specobjid', 'z',
#        'h_alpha_flux', 'h_beta_flux', 'oiii_5007_flux', 'nii_6548_flux',
#        'nii_6584_flux', 'sii_6717_flux', 'sii_6731_flux', 'oi_6300_flux',
#        'class', 'subclass', 'galname', 'fnu_12', 'fnu_25', 'fnu_60', 'fnu_100',
#        'rat_12_25', 'rat_25_60', 'rat_60_100', 'ra', 'dec', 'EtiqRef',
#        'rat_12_60', 'rat_12_100', 'rat_25_100'],
#       dtype='object')

# %%
# Logs sencillos:
Log_fnu_12=np.log(data['fnu_12'])
Log_fnu_25=np.log(data['fnu_25'])
Log_fnu_60=np.log(data['fnu_60'])
Log_fnu_100=np.log(data['fnu_100'])

# %%
# Logs de razones:
Log_12_25=np.log(data['rat_12_25'])
Log_12_60=np.log(data['rat_12_60'])
Log_12_100=np.log(data['rat_12_100'])
Log_25_60=np.log(data['rat_25_60'])
Log_25_100=np.log(data['rat_25_100'])
Log_60_100=np.log(data['rat_60_100'])

# %%
# Ingreso a la tabla Logs sencillos y Logs de razones:
data["Log_fnu_12"]= Log_fnu_12
data["Log_fnu_25"]= Log_fnu_25
data["Log_fnu_60"]= Log_fnu_60
data["Log_fnu_100"]= Log_fnu_100

data["Log_12_25"]= Log_12_25
data["Log_12_60"]= Log_12_60
data["Log_12_100"]= Log_12_100
data["Log_25_60"]= Log_25_60
data["Log_25_100"]= Log_25_100
data["Log_60_100"]= Log_60_100

# %%
data.columns
# Out:
# Index(['ra_sdss', 'dec_sdss', 'ra_iras', 'dec_iras', 'specobjid', 'z',
#        'h_alpha_flux', 'h_beta_flux', 'oiii_5007_flux', 'nii_6548_flux',
#        'nii_6584_flux', 'sii_6717_flux', 'sii_6731_flux', 'oi_6300_flux',
#        'class', 'subclass', 'galname', 'fnu_12', 'fnu_25', 'fnu_60', 'fnu_100',
#        'rat_12_25', 'rat_25_60', 'rat_60_100', 'ra', 'dec', 'EtiqRef',
#        'rat_12_60', 'rat_12_100', 'rat_25_100', 'Log_fnu_12', 'Log_fnu_25',
#        'Log_fnu_60', 'Log_fnu_100', 'Log_12_25', 'Log_12_60', 'Log_12_100',
#        'Log_25_60', 'Log_25_100', 'Log_60_100'],
#       dtype='object')

# %% [markdown]
# # Gráficas en Infrarrojo (IRAS) que elegimos

# %% [markdown]
# # 1. Log 12 Vs Log 60

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_fnu_60, Log_fnu_12, marker=".", color="violet")

ax.set_xlim([-2, 7.5])
ax.set_ylim([-2, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


plt.title('Log 12 Vs Log 60')
plt.xlabel('Log_fnu_60')
plt.ylabel('Log_fnu_12')
# Out:
# Text(0, 0.5, 'Log_fnu_12')

# %%
# Definir colores para cada etiqueta
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_fnu_60'], subset['Log_fnu_12'], c=color, label=etiqref)

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_fnu_60')
ax.set_ylabel('Log_fnu_12')
ax.legend()

# %%
#CON TRANSPARENCIAS, sE VISUALIZA Infrarroja

# Definir colores para cada etiqueta, ahora con transparencia para 'Seyfert'
colors = {'Infrarroja': 'red', 'LINER': (0, 1, 0, 0.1), 'Seyfert': (0, 0, 1, 0.01)}  # La tupla (0, 0, 1, 0.5) representa azul semitransparente

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_fnu_60'], subset['Log_fnu_12'], c=color, label=etiqref)

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

# Añadir etiquetas y leyenda
ax.set_xlabel('Log_fnu_60')
ax.set_ylabel('Log_fnu_12')
ax.legend()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#CON TRANSPARENCIAS, sE VISUALIZA LINER

# Definir colores para cada etiqueta, ahora con transparencia para 'Seyfert'
colors = {'Infrarroja': (1, 0, 0, 0.1), 'LINER': "green", 'Seyfert': (0, 0, 1, 0.02)}  # La tupla (0, 0, 1, 0.5) representa azul semitransparente

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_fnu_60'], subset['Log_fnu_12'], c=color, label=etiqref)

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

# Añadir etiquetas y leyenda
ax.set_xlabel('Log_fnu_60')
ax.set_ylabel('Log_fnu_12')
ax.legend()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#CON TRANSPARENCIAS, sE VISUALIZA Seyfert

# Definir colores para cada etiqueta, ahora con transparencia para 'Seyfert'
colors = {'Infrarroja': (1, 0, 0, 0.1), 'LINER': (0, 1, 0, 0.1), 'Seyfert': "blue"}  # La tupla (0, 0, 1, 0.5) representa azul semitransparente

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_fnu_60'], subset['Log_fnu_12'], c=color, label=etiqref)

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

# Añadir etiquetas y leyenda
ax.set_xlabel('Log_fnu_60')
ax.set_ylabel('Log_fnu_12')
ax.legend()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # 2. Log_12_25 / Log_12_60

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_12_25, Log_12_60, marker="+", color="turquoise")

ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log_12_25 Vs Log_12_60')
plt.xlabel('Log_12_25')
plt.ylabel('Log_12_60')
# Out:
# Text(0, 0.5, 'Log_12_60')

# %%
# Definir colores para cada etiqueta
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_25'], subset['Log_12_60'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_25')
ax.set_ylabel('Log_12_60')
ax.legend()

# %%
#CON TRANSPARENCIAS, sE VISUALIZA Infrarroja

# Definir colores para cada etiqueta, ahora con transparencia para 'Seyfert'
colors = {'Infrarroja': 'red', 'LINER': (0, 1, 0, 0.1), 'Seyfert': (0, 0, 1, 0.01)}  # La tupla (0, 0, 1, 0.5) representa azul semitransparente

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_25'], subset['Log_12_60'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_25')
ax.set_ylabel('Log_12_60')
ax.legend()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#CON TRANSPARENCIAS, sE VISUALIZA LINER

# Definir colores para cada etiqueta, ahora con transparencia para 'Seyfert'
colors = {'Infrarroja': (1, 0, 0, 0.1), 'LINER': "green", 'Seyfert': (0, 0, 1, 0.02)}  # La tupla (0, 0, 1, 0.5) representa azul semitransparente

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_25'], subset['Log_12_60'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_25')
ax.set_ylabel('Log_12_60')
ax.legend()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
#CON TRANSPARENCIAS, sE VISUALIZA Seyfert

# Definir colores para cada etiqueta, ahora con transparencia para 'Seyfert'
colors = {'Infrarroja': (1, 0, 0, 0.1), 'LINER': (0, 1, 0, 0.1), 'Seyfert': "blue"}  # La tupla (0, 0, 1, 0.5) representa azul semitransparente


# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_25'], subset['Log_12_60'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_25')
ax.set_ylabel('Log_12_60')
ax.legend()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %% [markdown]
# # 3. Otras Gráficas Sencillas:

# %%
# Log 12/ Log 25

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_fnu_25, Log_fnu_12, marker=".", color="pink")

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log 12 Vs Log 25')
plt.xlabel('Log_fnu_25')
plt.ylabel('Log_fnu_12')
# Out:
# Text(0, 0.5, 'Log_fnu_12')

# %%
# Definir colores para cada etiqueta
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_fnu_25'], subset['Log_fnu_12'], c=color, label=etiqref)

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_fnu_25')
ax.set_ylabel('Log_fnu_12')
# Out:
# Text(0, 0.5, 'Log_fnu_12')

# %%
# Log 12/ Log 100

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_fnu_100, Log_fnu_12, marker=".", color="crimson")

ax.set_xlim([-4, 7.5])
ax.set_ylim([-3, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log 12 Vs Log 100')
plt.xlabel('Log_fnu_100')
plt.ylabel('Log_fnu_12')
# Out:
# Text(0, 0.5, 'Log_fnu_12')

# %%
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_fnu_100'], subset['Log_fnu_12'], c=color, label=etiqref)

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_fnu_100')
ax.set_ylabel('Log_fnu_12')
# Out:
# Text(0, 0.5, 'Log_fnu_12')

# %%
# log 25/ Log 60

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_fnu_60, Log_fnu_25, marker=".", color="magenta")

ax.set_xlim([-4, 7.5])
ax.set_ylim([-3, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log 25 Vs Log 60')
plt.xlabel('Log_fnu_60')
plt.ylabel('Log_fnu_25')
# Out:
# Text(0, 0.5, 'Log_fnu_25')

# %%
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_fnu_60'], subset['Log_fnu_25'], c=color, label=etiqref)

ax.set_xlim([-1, 2.5])
ax.set_ylim([-2, 1])    
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_fnu_60')
ax.set_ylabel('Log_fnu_25')
# Out:
# Text(0, 0.5, 'Log_fnu_25')

# %% [markdown]
# # 4. Otras Gráficas en razones:

# %%
# Log_12_25 / Log_12_100

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_12_25, Log_12_100, marker="+", color="lightseagreen")

ax.set_xlim([-5, 5])
ax.set_ylim([-6, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log_12_25 Vs Log_12_100')
plt.xlabel('Log_12_25')
plt.ylabel('Log_12_100')
# Out:
# Text(0, 0.5, 'Log_12_100')

# %%
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_25'], subset['Log_12_100'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_25')
ax.set_ylabel('Log_12_100')
# Out:
# Text(0, 0.5, 'Log_12_100')

# %%
# Log_25_60 / Log_25_100

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_25_60, Log_25_100, marker="+", color="aqua")

ax.set_xlim([-5, 5])
ax.set_ylim([-6, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log_25_60 Vs Log_25_100')
plt.xlabel('Log_25_60')
plt.ylabel('Log_25_100')
# Out:
# Text(0, 0.5, 'Log_25_100')

# %%
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_60'], subset['Log_25_100'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_60')
ax.set_ylabel('Log_25_100')
# Out:
# Text(0, 0.5, 'Log_25_100')

# %%
# Log_25_100 / Log_60_100

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_25_100, Log_60_100, marker="+", color="deepskyblue")

ax.set_xlim([-5, 5])
ax.set_ylim([-5, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log_25_100 Vs Log_60_100')
plt.xlabel('Log_25_100')
plt.ylabel('Log_60_100')
# Out:
# Text(0, 0.5, 'Log_60_100')

# %%
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_25_100'], subset['Log_60_100'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_25_100')
ax.set_ylabel('Log_60_100')
# Out:
# Text(0, 0.5, 'Log_60_100')

# %%
# Log_12_100 / Log_25_60

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_12_100, Log_25_60, marker="+", color="olivedrab")

ax.set_xlim([-6, 5])
ax.set_ylim([-5, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log_12_100 Vs Log_25_60')
plt.xlabel('Log_12_100')
plt.ylabel('Log_25_60')
# Out:
# Text(0, 0.5, 'Log_25_60')

# %%
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_100'], subset['Log_25_60'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_100')
ax.set_ylabel('Log_25_60')
# Out:
# Text(0, 0.5, 'Log_25_60')

# %%
# Log_12_100 / Log_60_100

fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(Log_12_100, Log_60_100, marker="+", color="olivedrab")

ax.set_xlim([-6, 5])
ax.set_ylim([-5, 5])

plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')

plt.title('Log_12_100 / Log_60_100')
plt.xlabel('Log_12_100')
plt.ylabel('Log_60_100')
# Out:
# Text(0, 0.5, 'Log_60_100')

# %%
colors = {'Infrarroja': 'red', 'LINER': 'green', 'Seyfert': 'blue'}

# Crear una figura y ejes
fig, ax = plt.subplots()

# Iterar sobre las etiquetas únicas en la columna 'EtiqRef'
for etiqref, color in colors.items():
    subset = data[data['EtiqRef'] == etiqref]
    ax.scatter(subset['Log_12_100'], subset['Log_60_100'], c=color, label=etiqref)


ax.set_xlim([-3.5, 3.5])
ax.set_ylim([-5, 3.5])   
plt.axhline(0, color='black', linestyle='--')
plt.axvline(0, color='black', linestyle='--')


# Añadir etiquetas y leyenda
ax.set_xlabel('Log_12_100')
ax.set_ylabel('Log_60_100')
# Out:
# Text(0, 0.5, 'Log_60_100')
