# %% [markdown]
# # Resultados para la matriz de confusión.
# ### Método: k-means
# ### Dimensiones: 3D.

# %% [markdown]
# 1. Para 3D para NII
# 2. Para 3D para SII
# 3. Para 3D para OI

# %% [markdown]
# ### 1. Para 3D para NII:

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# Nueva matriz de confusión
confusion_matrix_result = [
    [61, 0, 14],
    [0, 23, 0],
    [0, 49, 11]
]


# Obtener las etiquetas reales y predichas para todas las clases
y_true = []
y_pred = []

for true_label, row in enumerate(confusion_matrix_result):
    for predicted_label, count in enumerate(row):
        y_true.extend([true_label] * count)
        y_pred.extend([predicted_label] * count)

# Calcular métricas directamente con scikit-learn
accuracy = accuracy_score(y_true, y_pred)
precision_micro = precision_score(y_true, y_pred, average='micro')
recall_micro = recall_score(y_true, y_pred, average='micro')
f1_micro = f1_score(y_true, y_pred, average='micro')

precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro = recall_score(y_true, y_pred, average='macro')
f1_macro = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted = recall_score(y_true, y_pred, average='weighted')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

# Mostrar resultados
print(f'Accuracy: {accuracy:.2f}\n')

print(f'Micro Precision: {precision_micro:.2f}')
print(f'Micro Recall: {recall_micro:.2f}')
print(f'Micro F1-score: {f1_micro:.2f}\n')

print(f'Macro Precision: {precision_macro:.2f}')
print(f'Macro Recall: {recall_macro:.2f}')
print(f'Macro F1-score: {f1_macro:.2f}\n')

print(f'Weighted Precision: {precision_weighted:.2f}')
print(f'Weighted Recall: {recall_weighted:.2f}')
print(f'Weighted F1-score: {f1_weighted:.2f}\n')

# Classification Report
print('\nClassification Report\n')
target_names = ['Class 1', 'Class 2', 'Class 3']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Accuracy: 0.60
#
# Micro Precision: 0.60
# Micro Recall: 0.60
# Micro F1-score: 0.60
#
# Macro Precision: 0.59
# Macro Recall: 0.67
# Macro F1-score: 0.55
#
# Weighted Precision: 0.69
# Weighted Recall: 0.60
# Weighted F1-score: 0.59
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.81      0.90        75
#      Class 2       0.32      1.00      0.48        23
#      Class 3       0.44      0.18      0.26        60
#
#     accuracy                           0.60       158
#    macro avg       0.59      0.67      0.55       158
# weighted avg       0.69      0.60      0.59       158

# %% [markdown]
# ### 2. Para 3D para SII:

# %%
# Nueva matriz de confusión
confusion_matrix_result = matriz = [
    [41, 25, 9],
    [0, 1, 22],
    [0, 0, 60]
]


# Obtener las etiquetas reales y predichas para todas las clases
y_true = []
y_pred = []

for true_label, row in enumerate(confusion_matrix_result):
    for predicted_label, count in enumerate(row):
        y_true.extend([true_label] * count)
        y_pred.extend([predicted_label] * count)

# Calcular métricas directamente con scikit-learn
accuracy = accuracy_score(y_true, y_pred)
precision_micro = precision_score(y_true, y_pred, average='micro')
recall_micro = recall_score(y_true, y_pred, average='micro')
f1_micro = f1_score(y_true, y_pred, average='micro')

precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro = recall_score(y_true, y_pred, average='macro')
f1_macro = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted = recall_score(y_true, y_pred, average='weighted')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

# Mostrar resultados
print(f'Accuracy: {accuracy:.2f}\n')

print(f'Micro Precision: {precision_micro:.2f}')
print(f'Micro Recall: {recall_micro:.2f}')
print(f'Micro F1-score: {f1_micro:.2f}\n')

print(f'Macro Precision: {precision_macro:.2f}')
print(f'Macro Recall: {recall_macro:.2f}')
print(f'Macro F1-score: {f1_macro:.2f}\n')

print(f'Weighted Precision: {precision_weighted:.2f}')
print(f'Weighted Recall: {recall_weighted:.2f}')
print(f'Weighted F1-score: {f1_weighted:.2f}\n')

# Classification Report
print('\nClassification Report\n')
target_names = ['Class 1', 'Class 2', 'Class 3']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Accuracy: 0.65
#
# Micro Precision: 0.65
# Micro Recall: 0.65
# Micro F1-score: 0.65
#
# Macro Precision: 0.57
# Macro Recall: 0.53
# Macro F1-score: 0.51
#
# Weighted Precision: 0.73
# Weighted Recall: 0.65
# Weighted F1-score: 0.64
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.55      0.71        75
#      Class 2       0.04      0.04      0.04        23
#      Class 3       0.66      1.00      0.79        60
#
#     accuracy                           0.65       158
#    macro avg       0.57      0.53      0.51       158
# weighted avg       0.73      0.65      0.64       158

# %% [markdown]
# ### 3. Para 3D para OI:

# %%
# Nueva matriz de confusión
confusion_matrix_result = [
    [36, 31, 8],
    [0, 0, 23],
    [0, 0, 60]
]

# Obtener las etiquetas reales y predichas para todas las clases
y_true = []
y_pred = []

for true_label, row in enumerate(confusion_matrix_result):
    for predicted_label, count in enumerate(row):
        y_true.extend([true_label] * count)
        y_pred.extend([predicted_label] * count)

# Calcular métricas directamente con scikit-learn
accuracy = accuracy_score(y_true, y_pred)
precision_micro = precision_score(y_true, y_pred, average='micro')
recall_micro = recall_score(y_true, y_pred, average='micro')
f1_micro = f1_score(y_true, y_pred, average='micro')

precision_macro = precision_score(y_true, y_pred, average='macro')
recall_macro = recall_score(y_true, y_pred, average='macro')
f1_macro = f1_score(y_true, y_pred, average='macro')

precision_weighted = precision_score(y_true, y_pred, average='weighted')
recall_weighted = recall_score(y_true, y_pred, average='weighted')
f1_weighted = f1_score(y_true, y_pred, average='weighted')

# Mostrar resultados
print(f'Accuracy: {accuracy:.2f}\n')

print(f'Micro Precision: {precision_micro:.2f}')
print(f'Micro Recall: {recall_micro:.2f}')
print(f'Micro F1-score: {f1_micro:.2f}\n')

print(f'Macro Precision: {precision_macro:.2f}')
print(f'Macro Recall: {recall_macro:.2f}')
print(f'Macro F1-score: {f1_macro:.2f}\n')

print(f'Weighted Precision: {precision_weighted:.2f}')
print(f'Weighted Recall: {recall_weighted:.2f}')
print(f'Weighted F1-score: {f1_weighted:.2f}\n')

# Classification Report
print('\nClassification Report\n')
target_names = ['Class 1', 'Class 2', 'Class 3']
print(classification_report(y_true, y_pred, target_names=target_names))
# Out:
# Accuracy: 0.61
#
# Micro Precision: 0.61
# Micro Recall: 0.61
# Micro F1-score: 0.61
#
# Macro Precision: 0.55
# Macro Recall: 0.49
# Macro F1-score: 0.48
#
# Weighted Precision: 0.73
# Weighted Recall: 0.61
# Weighted F1-score: 0.61
#
#
# Classification Report
#
#               precision    recall  f1-score   support
#
#      Class 1       1.00      0.48      0.65        75
#      Class 2       0.00      0.00      0.00        23
#      Class 3       0.66      1.00      0.79        60
#
#     accuracy                           0.61       158
#    macro avg       0.55      0.49      0.48       158
# weighted avg       0.73      0.61      0.61       158
