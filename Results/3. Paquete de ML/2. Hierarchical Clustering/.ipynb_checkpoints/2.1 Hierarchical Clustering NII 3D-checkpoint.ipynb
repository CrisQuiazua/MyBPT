# %% [markdown]
# Objetivo:
#
# Realizar Hierarchical Clustering 3D: Para NII.
# clusters=3.
#
# * 0. Traer Datos Pre-etiqDeBase: Con 1269 Observaciones en Visual e infrarrojo.
# * 1. Hacer Hierarchical Clustering para X = 'Ejex_NH', 'Ejey_OHB' y 'Log_12_25'.
# * 2. Medición de exactitud  del Método.
# * 3. Medición de exactitud  con una muestra de Pre-etiquetas (12.45% Pre-etiquetadas - 158 galaxias).
# * 4. Realizar gráfica.

# %% [markdown]
# ## 0. Datos:

# %%
import numpy as np
import pandas as pd
import time
from datetime import date
import warnings
warnings.filterwarnings 
import astropy.units as u
from astropy.table import Table
from astroquery.sdss import SDSS
from array import array
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from mpl_toolkits.mplot3d import Axes3D
# Habilitar la interactividad en Jupyter Notebook
# %matplotlib notebook
from matplotlib.lines import Line2D
import plotly.express as px
import plotly.graph_objects as go

# %%
FusionData = pd.read_csv('C:/Users/Cristina Quiazúa M/Desktop/MyBPT/Results/3. Paquete de ML/Mydata.csv')

# %%
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  fnu_100  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    15.08
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...     1.01
# 2      528.2295    139.90980       34.019120       62.50361  ...     1.79
# 3      998.6539    263.62670      358.444700       54.00912  ...     2.83
# 4      520.6220     74.79313       28.152840       74.78139  ...     2.10
#
#    rat_12_25  rat_25_60  rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH  \
# 0   0.700000   0.096899    0.342175 -2.275763 -1.065383 -1.694790 -5.024607
# 1   1.555556   0.329268    0.811881  0.625129 -1.488608 -1.481473 -4.039606
# 2   0.500000   0.666667    0.418994 -1.414075 -0.743963 -1.261980 -3.489259
# 3   0.591837   0.401639    0.431095  0.307240 -1.526911 -1.179064 -3.498782
# 4   0.813953   0.632353    0.323810 -0.977078 -0.550111 -1.223666 -2.962311
#
#    Log_12_25     EtiqRef
# 0  -0.356675         NaN
# 1   0.441833         NaN
# 2  -0.693147         NaN
# 3  -0.524524         NaN
# 4  -0.205852  Infrarroja
#
# [5 rows x 30 columns]

# %%
type(FusionData)# Debe estar en: pandas.core.frame.DataFrame
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## 1. Hacer K-Means para X = 'Ejex_NH', 'Ejey_OHb'.

# %%
# Seleccionar las columnas relevantes y escalar los datos
columns_of_interest = ['Ejex_NH', 'Ejey_OHb', 'Log_12_25']
data = FusionData[columns_of_interest]

# Escalar los datos para asegurarse de que todas las variables tengan la misma escala
scaler = StandardScaler()
scaled_data = scaler.fit_transform(data)

# %%
# Aplicar el algoritmo de Hierarchical Clustering
cluster_model = AgglomerativeClustering(n_clusters=3)
clusters = cluster_model.fit_predict(scaled_data)

# Añadir la columna de clusters al DataFrame original
FusionData['HC_N_3D'] = clusters
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  rat_12_25  \
# 0      153.8173     35.59267        3.656026       13.19764  ...   0.700000
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...   1.555556
# 2      528.2295    139.90980       34.019120       62.50361  ...   0.500000
# 3      998.6539    263.62670      358.444700       54.00912  ...   0.591837
# 4      520.6220     74.79313       28.152840       74.78139  ...   0.813953
#
#    rat_25_60  rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH  Log_12_25  \
# 0   0.096899    0.342175 -2.275763 -1.065383 -1.694790 -5.024607  -0.356675
# 1   0.329268    0.811881  0.625129 -1.488608 -1.481473 -4.039606   0.441833
# 2   0.666667    0.418994 -1.414075 -0.743963 -1.261980 -3.489259  -0.693147
# 3   0.401639    0.431095  0.307240 -1.526911 -1.179064 -3.498782  -0.524524
# 4   0.632353    0.323810 -0.977078 -0.550111 -1.223666 -2.962311  -0.205852
#
#       EtiqRef  HC_N_3D
# 0         NaN        0
# 1         NaN        2
# 2         NaN        0
# 3         NaN        0
# 4  Infrarroja        0
#
# [5 rows x 31 columns]

# %%
# Filtrar por categoría "Infrarroja"
infrarroja_df = FusionData.loc[FusionData['EtiqRef'] == 'Infrarroja']
infrarroja_counts = infrarroja_df['HC_N_3D'].value_counts()

# Filtrar por categoría "Seyfert"
seyfert_df = FusionData.loc[FusionData['EtiqRef'] == 'Seyfert']
seyfert_counts = seyfert_df['HC_N_3D'].value_counts()

# Filtrar por categoría "LINER"
liner_df = FusionData.loc[FusionData['EtiqRef'] == 'LINER']
liner_counts = liner_df['HC_N_3D'].value_counts()

# Imprimir los resultados
print("Para la categoría 'Infrarroja':")
print(infrarroja_counts)
print()

print("Para la categoría 'Seyfert':")
print(seyfert_counts)
print()

print("Para la categoría 'LINER':")
print(liner_counts)
# Out:
# Para la categoría 'Infrarroja':
# 0    68
# 2     7
# Name: HC_N_3D, dtype: int64
#
# Para la categoría 'Seyfert':
# 1    49
# 2    11
# Name: HC_N_3D, dtype: int64
#
# Para la categoría 'LINER':
# 1    23
# Name: HC_N_3D, dtype: int64

# %% [markdown]
# Item con mayor cantidad de aciertos:
#
# 0 = Infrarroja
# 1 = Seyfert
# 2 = LINER

# %% [markdown]
# ## 2. Medición de exactitud del Método.

# %%
labels_true = FusionData['HC_N_3D']

# Calcular la silueta
silhouette_avg = silhouette_score(scaled_data, labels_true)

print(f'Silhouette Score: {silhouette_avg:.2f}')
# Out:
# Silhouette Score: 0.40

# %%
silhouette_avg_percentage = silhouette_avg * 100
print(f'Silhouette Score (en porcentaje): {silhouette_avg_percentage:.2f}%')
# Out:
# Silhouette Score (en porcentaje): 39.99%

# %% [markdown]
# ## 3. Medición de exactitud con Frecuencia cruzada

# %% [markdown]
# ### EtiqRef Vs ClusterN2D

# %% [markdown]
# Convertir dataframe en:
#
# 0 = Infrarroja
# 1 = Seyfert
# 2 = LINER

# %%
# Crear un diccionario que mapee los valores antiguos a los nuevos nombres

replace_dict = {
    0: "Infrarroja", 
    1: "Seyfert", 
    2: "LINER"
}

# Reemplazar los valores en la columna "ClusterN3" utilizando el diccionario
FusionData["HC_N_3D"] = FusionData["HC_N_3D"].replace(replace_dict)

# %%
FusionData[0:3]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  rat_12_25  \
# 0      153.8173     35.59267        3.656026       13.19764  ...   0.700000
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...   1.555556
# 2      528.2295    139.90980       34.019120       62.50361  ...   0.500000
#
#    rat_25_60  rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH  Log_12_25  \
# 0   0.096899    0.342175 -2.275763 -1.065383 -1.694790 -5.024607  -0.356675
# 1   0.329268    0.811881  0.625129 -1.488608 -1.481473 -4.039606   0.441833
# 2   0.666667    0.418994 -1.414075 -0.743963 -1.261980 -3.489259  -0.693147
#
#    EtiqRef     HC_N_3D
# 0      NaN  Infrarroja
# 1      NaN       LINER
# 2      NaN  Infrarroja
#
# [3 rows x 31 columns]

# %%
# Cuantos infrarrojas, Seyfert y LINER fueron clasificadas en EtiqRef:
conteoEtiqRef = FusionData['EtiqRef'].value_counts()
conteoEtiqRef
# Out:
# Infrarroja    75
# Seyfert       60
# LINER         23
# Name: EtiqRef, dtype: int64

# %%
# Cuantos infrarrojas, Seyfert y LINER fueron clasificadas en ClusterN2D:
conteoHC_N_2D = FusionData['HC_N_3D'].value_counts()
conteoHC_N_2D
# Out:
# Infrarroja    1004
# Seyfert        197
# LINER           68
# Name: HC_N_3D, dtype: int64

# %%
tabla_frecuencias = pd.crosstab(FusionData['EtiqRef'], FusionData['HC_N_3D'], margins=True, margins_name="Total")
tabla_frecuencias
# Out:
# HC_N_3D     Infrarroja  LINER  Seyfert  Total
# EtiqRef
# Infrarroja          68      7        0     75
# LINER                0      0       23     23
# Seyfert              0     11       49     60
# Total               68     18       72    158

# %%
# Para obtener las cantidades de coincidencias específicas, puedes acceder a los valores en la tabla
coincidencias_infrarroja = tabla_frecuencias.loc['Infrarroja', 'Infrarroja']
coincidencias_seyfert = tabla_frecuencias.loc['Seyfert', 'Seyfert']
coincidencias_liner = tabla_frecuencias.loc['LINER', 'LINER']

print("Coincidencias Infrarroja:", coincidencias_infrarroja)
print("Coincidencias Seyfert:", coincidencias_seyfert)
print("Coincidencias LINER:", coincidencias_liner)
# Out:
# Coincidencias Infrarroja: 68
# Coincidencias Seyfert: 49
# Coincidencias LINER: 0

# %% [markdown]
# ### Mi muestra (EtiqRef) trae :
#
# Infrarroja    75
# Seyfert       60
# LINER         23

# %%
# Sumar las coincidencias para cada categoría
total_coincidencias = coincidencias_infrarroja + coincidencias_seyfert + coincidencias_liner

# Obtener el total de observaciones
total_observaciones = tabla_frecuencias.loc['Total', 'Total']

# Calcular el porcentaje de exactitud general
exactitud_general = (total_coincidencias / total_observaciones) * 100

print("Porcentaje de Exactitud General:", exactitud_general)
# Out:
# Porcentaje de Exactitud General: 74.0506329113924

# %% [markdown]
# ### Cálculos

# %%
# Calcula los verdaderos positivos, falsos positivos, falsos negativos y verdaderos negativos
verdaderos_positivos = tabla_frecuencias.loc['Infrarroja', 'Infrarroja']
falsos_positivos = tabla_frecuencias.loc['Total', 'Infrarroja'] - verdaderos_positivos
falsos_negativos = tabla_frecuencias.loc['Infrarroja', 'Total'] - verdaderos_positivos
verdaderos_negativos = tabla_frecuencias.loc['Total', 'Total'] - verdaderos_positivos - falsos_positivos - falsos_negativos

# %%
# Calcula la Precisión
precision = verdaderos_positivos / (verdaderos_positivos + falsos_positivos)
# Calcula la Sensibilidad
sensibilidad = verdaderos_positivos / (verdaderos_positivos + falsos_negativos)

# %%
# Calcula los Falsos Positivos y Falsos Negativos
falsos_positivos = falsos_positivos / (falsos_positivos + verdaderos_negativos)
falsos_negativos = falsos_negativos / (falsos_negativos + verdaderos_positivos)

# %%
# Imprime los resultados
print("Precisión:", precision)
print("Sensibilidad:", sensibilidad)
print("Falsos Positivos:", falsos_positivos)
print("Falsos Negativos:", falsos_negativos)
# Out:
# Precisión: 1.0
# Sensibilidad: 0.9066666666666666
# Falsos Positivos: 0.0
# Falsos Negativos: 0.09333333333333334

# %% [markdown]
# ## 4. Realizar gráfica

# %%
# Mapear los valores de ClusterN3D a los colores correspondientes
colors_dict = {
    'Infrarroja': 'indigo',
    'Seyfert': 'salmon',
    'LINER': 'lightsalmon'
}

fig = go.Figure(data=[
    go.Scatter3d(
        x=FusionData['Ejex_NH'],
        y=FusionData['Ejey_OHb'],
        z=FusionData['Log_12_25'],
        mode='markers',
        marker=dict(
            color=FusionData['HC_N_3D'].map(colors_dict),
            size=3,
            symbol='circle'
        )
    )
])


# Actualizar las etiquetas de los ejes
fig.update_layout(
    scene=dict(
        xaxis_title='Ejex_NH',
        yaxis_title='Ejey_OHb',
        zaxis_title='Log_12_25'
    ),
    title='Hierarchical Clustering NII 3D',  # Agregar el título de la gráfica
)

fig.show()
# Out:
# <div>                            <div id="dfddef2a-3314-4336-96ce-24eaec5b6367" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dfddef2a-3314-4336-96ce-24eaec5b6367")) {                    Plotly.newPlot(                        "dfddef2a-3314-4336-96ce-24eaec5b6367",                        [{"marker":{"color":["indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","salmon","salmon","indigo","salmon","salmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","salmon","indigo","indigo","salmon","salmon","indigo","indigo","lightsalmon","indigo","salmon","lightsalmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","salmon","lightsalmon","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","lightsalmon","indigo","indigo","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","indigo","salmon","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","salmon","indigo","indigo","indigo","lightsalmon","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","salmon","salmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","indigo","salmon","lightsalmon","indigo","salmon","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","indigo","indigo","salmon","indigo","lightsalmon","indigo","salmon","indigo","salmon","indigo","lightsalmon","lightsalmon","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo", ...

# %%
# Mapear los valores de ClusterN3D a los colores correspondientes
colors_dict = {
    'Infrarroja': 'indigo',
    'Seyfert': 'salmon',
    'LINER': 'lightsalmon'
}

fig = go.Figure(data=[
    go.Scatter3d(
        x=FusionData['Ejex_NH'],
        y=FusionData['Ejey_OHb'],
        z=FusionData['Log_12_25'],
        mode='markers',
        marker=dict(
            color=FusionData['HC_N_3D'].map(colors_dict),
            size=3,
            symbol='circle'
        )
    )
])


# Actualizar las etiquetas de los ejes
fig.update_layout(
    scene=dict(
        xaxis_title='Ejex_NH',
        yaxis_title='Ejey_OHb',
        zaxis_title='Log_12_25'
    ),
    title='Hierarchical Clustering NII 3D',  # Agregar el título de la gráfica
)

# Agregar la leyenda personalizada
for group, color in colors_dict.items():
    fig.add_trace(go.Scatter(
        x=[None],
        y=[None],
        mode='markers',
        marker=dict(
            color=color,
            size=10,
            symbol='circle'
        ),
        name=f'{group} = {color}'
    ))

fig.show()
# Out:
# <div>                            <div id="030144ac-2f0f-44d5-877d-8657e6bb6eaf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("030144ac-2f0f-44d5-877d-8657e6bb6eaf")) {                    Plotly.newPlot(                        "030144ac-2f0f-44d5-877d-8657e6bb6eaf",                        [{"marker":{"color":["indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","salmon","salmon","indigo","salmon","salmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","salmon","indigo","indigo","salmon","salmon","indigo","indigo","lightsalmon","indigo","salmon","lightsalmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","salmon","lightsalmon","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","indigo","indigo","lightsalmon","indigo","indigo","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","indigo","salmon","indigo","indigo","indigo","indigo","salmon","salmon","indigo","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","salmon","indigo","indigo","indigo","lightsalmon","indigo","lightsalmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","salmon","salmon","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","lightsalmon","indigo","salmon","lightsalmon","indigo","salmon","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo","salmon","indigo","lightsalmon","indigo","indigo","salmon","indigo","lightsalmon","indigo","salmon","indigo","salmon","indigo","lightsalmon","lightsalmon","indigo","indigo","salmon","indigo","indigo","indigo","indigo","indigo","indigo","indigo","indigo", ...

# %% [markdown]
# # Conclusiones:

# %% [markdown]
# ## 2. Por medicion del Metodo: Coeficiente de Silueta: 40%

# %% [markdown]
# ## 3. Por Frecuencia cruzada
#
# Se tiene una exactitud del modelo de: 74%
