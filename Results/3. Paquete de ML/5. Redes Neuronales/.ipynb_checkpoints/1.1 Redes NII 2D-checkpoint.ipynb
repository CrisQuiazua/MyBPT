# %% [markdown]
# Objetivo:
#
# Realizar redes neuronales en 2D: Para NII.
# Para los datos preetiquetados: 12.45% Pre-etiquetadas - 158 galaxias, se van a dividir así:
# 54% = Datos de entrenamiento = 85 Datos.
# 46% = Datos para tomar la exactitud = 73 Datos.
#
# * 0. Traer Datos Pre-etiqDeBase: Con 1269 Observaciones en Visual e infrarrojo.
# * 1. Hacer redes = 'Ejex_NH', 'Ejey_OHB'.
# * 2. Medición de exactitud con el 46% restante de los datos.
# * 3. Realizar gráfica.

# %% [markdown]
# ## 0. Datos:

# %%
import numpy as np
import pandas as pd
import time
from datetime import date
import warnings
warnings.filterwarnings 
import astropy.units as u
from astropy.table import Table
#from astroquery.sdss import SDSS
from array import array
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics

from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
FusionData = pd.read_csv('C:/Users/Wind1/Downloads/AaaCristinaCodigos/Mydata.csv')

# %%
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  fnu_100  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    15.08
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...     1.01
# 2      528.2295    139.90980       34.019120       62.50361  ...     1.79
# 3      998.6539    263.62670      358.444700       54.00912  ...     2.83
# 4      520.6220     74.79313       28.152840       74.78139  ...     2.10
#
#    rat_12_25  rat_25_60  rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH  \
# 0   0.700000   0.096899    0.342175 -2.275763 -1.065383 -1.694790 -5.024607
# 1   1.555556   0.329268    0.811881  0.625129 -1.488608 -1.481473 -4.039606
# 2   0.500000   0.666667    0.418994 -1.414075 -0.743963 -1.261980 -3.489259
# 3   0.591837   0.401639    0.431095  0.307240 -1.526911 -1.179064 -3.498782
# 4   0.813953   0.632353    0.323810 -0.977078 -0.550111 -1.223666 -2.962311
#
#    Log_12_25     EtiqRef
# 0  -0.356675         NaN
# 1   0.441833         NaN
# 2  -0.693147         NaN
# 3  -0.524524         NaN
# 4  -0.205852  Infrarroja
#
# [5 rows x 30 columns]

# %%
conteoEtiqRef = FusionData['EtiqRef'].value_counts()
conteoEtiqRef
# Out:
# Infrarroja    75
# Seyfert       60
# LINER         23
# Name: EtiqRef, dtype: int64

# %%
grupo1 = FusionData.sample(frac=0.6, random_state=1)
grupo2 = FusionData.drop(grupo1.index)

# %%
FusionData['EtiqRef60%'] = grupo1['EtiqRef']
FusionData['EtiqRef40%'] = grupo2['EtiqRef']

# %%
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  rat_25_60  \
# 0      153.8173     35.59267        3.656026       13.19764  ...   0.096899
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...   0.329268
# 2      528.2295    139.90980       34.019120       62.50361  ...   0.666667
# 3      998.6539    263.62670      358.444700       54.00912  ...   0.401639
# 4      520.6220     74.79313       28.152840       74.78139  ...   0.632353
#
#    rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH Log_12_25     EtiqRef  \
# 0    0.342175 -2.275763 -1.065383 -1.694790 -5.024607 -0.356675         NaN
# 1    0.811881  0.625129 -1.488608 -1.481473 -4.039606  0.441833         NaN
# 2    0.418994 -1.414075 -0.743963 -1.261980 -3.489259 -0.693147         NaN
# 3    0.431095  0.307240 -1.526911 -1.179064 -3.498782 -0.524524         NaN
# 4    0.323810 -0.977078 -0.550111 -1.223666 -2.962311 -0.205852  Infrarroja
#
#    EtiqRef60%  EtiqRef40%
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN  Infrarroja
#
# [5 rows x 32 columns]

# %% [markdown]
# ### División por grupos EtiqRef 60% y 40%

# %%
conteoEtiqRef60 = FusionData['EtiqRef60%'].value_counts()
conteoEtiqRef60
# Out:
# Infrarroja    43
# Seyfert       27
# LINER         15
# Name: EtiqRef60%, dtype: int64

# %%
conteoEtiqRef40 = FusionData['EtiqRef40%'].value_counts()
conteoEtiqRef40
# Out:
# Seyfert       33
# Infrarroja    32
# LINER          8
# Name: EtiqRef40%, dtype: int64

# %% [markdown]
# ## 1. Hacer Redes neuronales para X = 'Ejex_NH', 'Ejey_OHb'.

# %%
# Elimina las filas con NaN en la columna 'EtiqRef60%' para el entrenamiento
FusionData_train = FusionData.dropna(subset=['EtiqRef60%'])

# %%
# Divide tus datos de entrenamiento en conjuntos de entrenamiento y prueba
X_train = FusionData_train[['Ejex_NH', 'Ejey_OHb']]
y_train = FusionData_train['EtiqRef60%']

# %%
# Codifica las etiquetas de clase
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)

# %%
# Escala tus datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
# Construye y entrena tu modelo de red neuronal
model = Sequential()
model.add(Dense(128, input_dim=2, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 clases: Infrarroja, Seyfert, LINER

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train_scaled, y_train_encoded, epochs=50, batch_size=32)
# Out:
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 1s 3ms/step - loss: 1.0986 - accuracy: 0.2824
# Epoch 2/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9959 - accuracy: 0.7529
# Epoch 3/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9124 - accuracy: 0.7765
# Epoch 4/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8407 - accuracy: 0.7765
# Epoch 5/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7745 - accuracy: 0.7882
# Epoch 6/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7126 - accuracy: 0.8235
# Epoch 7/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6547 - accuracy: 0.8706
# Epoch 8/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5986 - accuracy: 0.8706
# Epoch 9/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.5463 - accuracy: 0.9176
# Epoch 10/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4958 - accuracy: 0.9529
# Epoch 11/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.9529
# Epoch 12/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4045 - accuracy: 0.9529
# Epoch 13/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3639 - accuracy: 0.9647
# Epoch 14/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3276 - accuracy: 0.9765
# Epoch 15/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2946 - accuracy: 0.9765
# Epoch 16/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2652 - accuracy: 0.9882
# Epoch 17/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2386 - accuracy: 1.0000
# Epoch 18/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2150 - accuracy: 1.0000
# Epoch 19/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1932 - accuracy: 1.0000
# Epoch 20/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1742 - accuracy: 1.0000
# Epoch 21/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1575 - accuracy: 1.0000
# Epoch 22/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1425 - accuracy: 1.0000
# Epoch 23/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.1303 - accuracy: 1.0000
# Epoch 24/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1181 - accuracy: 1.0000
# Epoch 25/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1075 - accuracy: 1.0000
# Epoch 26/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0989 - accuracy: 1.0000
# Epoch 27/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0903 - accuracy: 1.0000
# Epoch 28/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0832 - accuracy: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0772 - accuracy: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0715 - accuracy: 1.0000
# Epoch 31/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0665 - accuracy: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0622 - accuracy: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0582 - accuracy: 1.0000
# Epoch 34/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0549 - accuracy: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.0513 - accuracy: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0431 - accuracy: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 0s 974us/step - loss: 0.0407 - accuracy: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0368 - accuracy: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0352 - accuracy: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0322 - accuracy: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0290 - accuracy: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0266 - accuracy: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0255 - accuracy: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0249 - accuracy: 1.0000

# %%
# Construye y entrena tu modelo de red neuronal
model = Sequential()
model.add(Dense(128, input_dim=2, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(3, activation='softmax'))  # 3 clases: Infrarroja, Seyfert, LINER

model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X_train_scaled, y_train_encoded, epochs=50, batch_size=32)
# Out:
# Epoch 1/50
# 3/3 [==============================] - 0s 2ms/step - loss: 1.0666 - accuracy: 0.4235
# Epoch 2/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9787 - accuracy: 0.7529
# Epoch 3/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.9030 - accuracy: 0.7529
# Epoch 4/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.8343 - accuracy: 0.7765
# Epoch 5/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.7715 - accuracy: 0.8118
# Epoch 6/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.7147 - accuracy: 0.8235
# Epoch 7/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.6599 - accuracy: 0.8471
# Epoch 8/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.6085 - accuracy: 0.8706
# Epoch 9/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5589 - accuracy: 0.8824
# Epoch 10/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.5092 - accuracy: 0.9059
# Epoch 11/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4626 - accuracy: 0.9529
# Epoch 12/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.4173 - accuracy: 0.9529
# Epoch 13/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.3772 - accuracy: 0.9647
# Epoch 14/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3385 - accuracy: 0.9765
# Epoch 15/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.3034 - accuracy: 0.9765
# Epoch 16/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2708 - accuracy: 0.9882
# Epoch 17/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.2433 - accuracy: 1.0000
# Epoch 18/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.2182 - accuracy: 1.0000
# Epoch 19/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1954 - accuracy: 1.0000
# Epoch 20/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1768 - accuracy: 0.9882
# Epoch 21/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1597 - accuracy: 0.9882
# Epoch 22/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1449 - accuracy: 0.9882
# Epoch 23/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1313 - accuracy: 1.0000
# Epoch 24/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.1207 - accuracy: 1.0000
# Epoch 25/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1097 - accuracy: 1.0000
# Epoch 26/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.1011 - accuracy: 1.0000
# Epoch 27/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0931 - accuracy: 1.0000
# Epoch 28/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0858 - accuracy: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0741 - accuracy: 1.0000
# Epoch 31/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0690 - accuracy: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0644 - accuracy: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0606 - accuracy: 1.0000
# Epoch 34/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0572 - accuracy: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0539 - accuracy: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0507 - accuracy: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0404 - accuracy: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0379 - accuracy: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0317 - accuracy: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0303 - accuracy: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.0292 - accuracy: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 0s 973us/step - loss: 0.0279 - accuracy: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 0s 2ms/step - loss: 0.0265 - accuracy: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 0s 1ms/step - loss: 0.0256 - accuracy: 1.0000

# %%
# Preprocesamiento de datos para todos los datos (incluyendo NaN)
X_all = FusionData[['Ejex_NH', 'Ejey_OHb']]
X_all_scaled = scaler.transform(X_all)

# Predecir etiquetas para todos los datos (incluyendo NaN)
all_predictions = model.predict(X_all_scaled)
all_predictions_classes = all_predictions.argmax(axis=-1)
# Out:
# 40/40 [==============================] - 0s 574us/step

# %%
# Preprocesamiento de datos para todos los datos (incluyendo NaN)
X_all = FusionData[['Ejex_NH', 'Ejey_OHb']]
X_all_scaled = scaler.transform(X_all)

# Predecir etiquetas para todos los datos (incluyendo NaN)
all_predictions = model.predict(X_all_scaled)
all_predictions_classes = all_predictions.argmax(axis=-1)
# Out:
# 40/40 [==============================] - 0s 574us/step

# %%
# Decodificar las etiquetas predichas
decoded_predictions = label_encoder.inverse_transform(all_predictions_classes)

# %%
# Añadir las predicciones al DataFrame original
FusionData['Predicciones'] = decoded_predictions
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  rat_60_100  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    0.342175
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...    0.811881
# 2      528.2295    139.90980       34.019120       62.50361  ...    0.418994
# 3      998.6539    263.62670      358.444700       54.00912  ...    0.431095
# 4      520.6220     74.79313       28.152840       74.78139  ...    0.323810
#
#    Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH Log_12_25     EtiqRef  EtiqRef60%  \
# 0 -2.275763 -1.065383 -1.694790 -5.024607 -0.356675         NaN         NaN
# 1  0.625129 -1.488608 -1.481473 -4.039606  0.441833         NaN         NaN
# 2 -1.414075 -0.743963 -1.261980 -3.489259 -0.693147         NaN         NaN
# 3  0.307240 -1.526911 -1.179064 -3.498782 -0.524524         NaN         NaN
# 4 -0.977078 -0.550111 -1.223666 -2.962311 -0.205852  Infrarroja         NaN
#
#    EtiqRef40%  Predicciones
# 0         NaN    Infrarroja
# 1         NaN    Infrarroja
# 2         NaN    Infrarroja
# 3         NaN    Infrarroja
# 4  Infrarroja    Infrarroja
#
# [5 rows x 33 columns]

# %%
conteoP = FusionData['Predicciones'].value_counts()
conteoP
# Out:
# Infrarroja    1087
# Seyfert         93
# LINER           89
# Name: Predicciones, dtype: int64

# %% [markdown]
# ## 2. Medición de exactitud con Frecuencia cruzada

# %%
tabla_frecuencias = pd.crosstab(FusionData['EtiqRef40%'], FusionData['Predicciones'], margins=True, margins_name="Total")
tabla_frecuencias
# Out:
# Predicciones  Infrarroja  LINER  Seyfert  Total
# EtiqRef40%
# Infrarroja            32      0        0     32
# LINER                  0      8        0      8
# Seyfert                0      0       33     33
# Total                 32      8       33     73

# %%
# Para obtener las cantidades de coincidencias específicas, puedes acceder a los valores en la tabla
coincidencias_infrarroja = tabla_frecuencias.loc['Infrarroja', 'Infrarroja']
coincidencias_seyfert = tabla_frecuencias.loc['Seyfert', 'Seyfert']
coincidencias_liner = tabla_frecuencias.loc['LINER', 'LINER']

print("Coincidencias Infrarroja:", coincidencias_infrarroja)
print("Coincidencias Seyfert:", coincidencias_seyfert)
print("Coincidencias LINER:", coincidencias_liner)
# Out:
# Coincidencias Infrarroja: 32
# Coincidencias Seyfert: 33
# Coincidencias LINER: 8

# %% [markdown]
# ### Cálculos

# %%
# Calcula los verdaderos positivos, falsos positivos, falsos negativos y verdaderos negativos
verdaderos_positivos = tabla_frecuencias.loc['Infrarroja', 'Infrarroja']
falsos_positivos = tabla_frecuencias.loc['Total', 'Infrarroja'] - verdaderos_positivos
falsos_negativos = tabla_frecuencias.loc['Infrarroja', 'Total'] - verdaderos_positivos
verdaderos_negativos = tabla_frecuencias.loc['Total', 'Total'] - verdaderos_positivos - falsos_positivos - falsos_negativos

# %%
# Calcula la Precisión
precision = verdaderos_positivos / (verdaderos_positivos + falsos_positivos)
# Calcula la Sensibilidad
sensibilidad = verdaderos_positivos / (verdaderos_positivos + falsos_negativos)

# %%
# Calcula los Falsos Positivos y Falsos Negativos
falsos_positivos = falsos_positivos / (falsos_positivos + verdaderos_negativos)
falsos_negativos = falsos_negativos / (falsos_negativos + verdaderos_positivos)

# %%
# Imprime los resultados
print("Precisión:", precision)
print("Sensibilidad:", sensibilidad)
print("Falsos Positivos:", falsos_positivos)
print("Falsos Negativos:", falsos_negativos)
# Out:
# Precisión: 1.0
# Sensibilidad: 1.0
# Falsos Positivos: 0.0
# Falsos Negativos: 0.0

# %% [markdown]
# ## 3. Realizar gráfica

# %%
infrarroja_df = FusionData[FusionData['Predicciones'] == 'Infrarroja']
seyfert_df = FusionData[FusionData['Predicciones'] == 'Seyfert']
liner_df = FusionData[FusionData['Predicciones'] == 'LINER']

sns.scatterplot(data=infrarroja_df, x='Ejex_NH', y='Ejey_OHb', color='indigo', label='Infrarroja', marker='o')
sns.scatterplot(data=seyfert_df, x='Ejex_NH', y='Ejey_OHb', color='salmon', label='Seyfert', marker='o')
sns.scatterplot(data=liner_df, x='Ejex_NH', y='Ejey_OHb', color='lightsalmon', label='LINER', marker='o')

plt.xlabel('Ejex_NH')
plt.ylabel('Ejey_OHb')
plt.title('Redes neuronales NII 2D')
plt.legend()
plt.show()

# %% [markdown]
# # Conclusiones:

# %% [markdown]
# ## 2. Medición: 100%
