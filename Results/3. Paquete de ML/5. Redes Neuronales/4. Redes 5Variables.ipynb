# %% [markdown]
# Objetivo:
#
# Realizar redes neuronales en 3D: Para NII.
# Para los datos preetiquetados: 12.45% Pre-etiquetadas - 158 galaxias, se van a dividir así:
# 54% = Datos de entrenamiento = 85 Datos.
# 46% = Datos para tomar la exactitud = 73 Datos.
#
# * 0. Traer Datos Pre-etiqDeBase: Con 1269 Observaciones en Visual e infrarrojo.
# * 1. Hacer redes= 'Ejex_NH', 'Ejey_OHB'.
# * 2. Medición de exactitud con el 46% restante de los datos.
# * 3. Realizar gráfica.

# %% [markdown]
# ## 0. Datos:

# %%
import numpy as np
import pandas as pd
import time
from datetime import date
import warnings
warnings.filterwarnings 
import astropy.units as u
from astropy.table import Table
#from astroquery.sdss import SDSS
from array import array
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib notebook
from matplotlib.lines import Line2D
import plotly.express as px
import plotly.graph_objects as go
from sklearn.cluster import AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn import metrics
from sklearn.preprocessing import LabelEncoder
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import to_categorical
# Out:
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
FusionData = pd.read_csv('C:/Users/Wind1/Downloads/AaaCristinaCodigos/Mydata.csv')

# %%
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  fnu_100  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    15.08
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...     1.01
# 2      528.2295    139.90980       34.019120       62.50361  ...     1.79
# 3      998.6539    263.62670      358.444700       54.00912  ...     2.83
# 4      520.6220     74.79313       28.152840       74.78139  ...     2.10
#
#    rat_12_25  rat_25_60  rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH  \
# 0   0.700000   0.096899    0.342175 -2.275763 -1.065383 -1.694790 -5.024607
# 1   1.555556   0.329268    0.811881  0.625129 -1.488608 -1.481473 -4.039606
# 2   0.500000   0.666667    0.418994 -1.414075 -0.743963 -1.261980 -3.489259
# 3   0.591837   0.401639    0.431095  0.307240 -1.526911 -1.179064 -3.498782
# 4   0.813953   0.632353    0.323810 -0.977078 -0.550111 -1.223666 -2.962311
#
#    Log_12_25     EtiqRef
# 0  -0.356675         NaN
# 1   0.441833         NaN
# 2  -0.693147         NaN
# 3  -0.524524         NaN
# 4  -0.205852  Infrarroja
#
# [5 rows x 30 columns]

# %%
conteoEtiqRef = FusionData['EtiqRef'].value_counts()
conteoEtiqRef
# Out:
# Infrarroja    75
# Seyfert       60
# LINER         23
# Name: EtiqRef, dtype: int64

# %%
grupo1 = FusionData.sample(frac=0.6, random_state=1)
grupo2 = FusionData.drop(grupo1.index)

# %%
FusionData['EtiqRef60%'] = grupo1['EtiqRef']
FusionData['EtiqRef40%'] = grupo2['EtiqRef']

# %%
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  rat_25_60  \
# 0      153.8173     35.59267        3.656026       13.19764  ...   0.096899
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...   0.329268
# 2      528.2295    139.90980       34.019120       62.50361  ...   0.666667
# 3      998.6539    263.62670      358.444700       54.00912  ...   0.401639
# 4      520.6220     74.79313       28.152840       74.78139  ...   0.632353
#
#    rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH Log_12_25     EtiqRef  \
# 0    0.342175 -2.275763 -1.065383 -1.694790 -5.024607 -0.356675         NaN
# 1    0.811881  0.625129 -1.488608 -1.481473 -4.039606  0.441833         NaN
# 2    0.418994 -1.414075 -0.743963 -1.261980 -3.489259 -0.693147         NaN
# 3    0.431095  0.307240 -1.526911 -1.179064 -3.498782 -0.524524         NaN
# 4    0.323810 -0.977078 -0.550111 -1.223666 -2.962311 -0.205852  Infrarroja
#
#    EtiqRef60%  EtiqRef40%
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN  Infrarroja
#
# [5 rows x 32 columns]

# %% [markdown]
# ### División por grupos EtiqRef 60% y 40%

# %%
conteoEtiqRef60 = FusionData['EtiqRef60%'].value_counts()
conteoEtiqRef60
# Out:
# Infrarroja    43
# Seyfert       27
# LINER         15
# Name: EtiqRef60%, dtype: int64

# %%
conteoEtiqRef40 = FusionData['EtiqRef40%'].value_counts()
conteoEtiqRef40
# Out:
# Seyfert       33
# Infrarroja    32
# LINER          8
# Name: EtiqRef40%, dtype: int64

# %% [markdown]
# ## 1. Hacer Redes neuronales para X = 'Ejex_NH', 'Ejey_OHb'.

# %%
# Filtrar filas con etiquetas de entrenamiento
train_data = FusionData.dropna(subset=['EtiqRef60%'])

# %%
# Obtener los datos de entrenamiento y las etiquetas
X_train = train_data[['Ejex_NH', 'Ejex_SH', 'Ejex_OH', 'Ejey_OHb', 'Log_12_25']]
y_train = train_data['EtiqRef60%']

# %%
# Convertir etiquetas a números utilizando LabelEncoder
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_train_categorical = to_categorical(y_train_encoded)

# %%
# Escala tus datos
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)

# %%
# Construir el modelo de red neuronal
model = Sequential()
model.add(Dense(64, input_dim=5, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))
# Out:
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
# Compilar el modelo
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Entrenar el modelo
model.fit(X_train_scaled, y_train_categorical, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Epoch 1/50
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From Q:\Programas\ANACONDA\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 3/3 [==============================] - 1s 62ms/step - loss: 1.1561 - accuracy: 0.4853 - val_loss: 1.0665 - val_accuracy: 0.5882
# Epoch 2/50
# 3/3 [==============================] - 0s 10ms/step - loss: 1.0950 - accuracy: 0.4853 - val_loss: 1.0214 - val_accuracy: 0.5882
# Epoch 3/50
# 3/3 [==============================] - 0s 10ms/step - loss: 1.0429 - accuracy: 0.4853 - val_loss: 0.9818 - val_accuracy: 0.6471
# Epoch 4/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.9949 - accuracy: 0.5588 - val_loss: 0.9438 - val_accuracy: 0.7059
# Epoch 5/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.9499 - accuracy: 0.6912 - val_loss: 0.9066 - val_accuracy: 0.7059
# Epoch 6/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.9084 - accuracy: 0.6912 - val_loss: 0.8710 - val_accuracy: 0.8235
# Epoch 7/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.8683 - accuracy: 0.7500 - val_loss: 0.8360 - val_accuracy: 0.9412
# Epoch 8/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.8309 - accuracy: 0.8382 - val_loss: 0.8054 - val_accuracy: 0.9412
# Epoch 9/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7965 - accuracy: 0.8971 - val_loss: 0.7747 - val_accuracy: 1.0000
# Epoch 10/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.7635 - accuracy: 0.9706 - val_loss: 0.7420 - val_accuracy: 1.0000
# Epoch 11/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.7302 - accuracy: 0.9706 - val_loss: 0.7098 - val_accuracy: 0.9412
# Epoch 12/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6965 - accuracy: 0.9706 - val_loss: 0.6779 - val_accuracy: 0.9412
# Epoch 13/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.6629 - accuracy: 0.9706 - val_loss: 0.6466 - val_accuracy: 0.9412
# Epoch 14/50
# 3/3 [==============================] - 0s 11ms/step - loss: 0.6305 - accuracy: 0.9706 - val_loss: 0.6155 - val_accuracy: 0.9412
# Epoch 15/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.5999 - accuracy: 0.9706 - val_loss: 0.5876 - val_accuracy: 0.9412
# Epoch 16/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5700 - accuracy: 0.9706 - val_loss: 0.5611 - val_accuracy: 0.9412
# Epoch 17/50
# 3/3 [==============================] - 0s 11ms/step - loss: 0.5406 - accuracy: 0.9706 - val_loss: 0.5338 - val_accuracy: 0.9412
# Epoch 18/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.5132 - accuracy: 0.9559 - val_loss: 0.5067 - val_accuracy: 0.9412
# Epoch 19/50
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4871 - accuracy: 0.9412 - val_loss: 0.4809 - val_accuracy: 0.9412
# Epoch 20/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.4614 - accuracy: 0.9265 - val_loss: 0.4576 - val_accuracy: 0.9412
# Epoch 21/50
# 3/3 [==============================] - 0s 11ms/step - loss: 0.4379 - accuracy: 0.9265 - val_loss: 0.4366 - val_accuracy: 0.9412
# Epoch 22/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.4148 - accuracy: 0.9412 - val_loss: 0.4185 - val_accuracy: 0.9412
# Epoch 23/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3930 - accuracy: 0.9412 - val_loss: 0.4028 - val_accuracy: 0.9412
# Epoch 24/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3730 - accuracy: 0.9412 - val_loss: 0.3895 - val_accuracy: 0.9412
# Epoch 25/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3515 - accuracy: 0.9706 - val_loss: 0.3754 - val_accuracy: 0.9412
# Epoch 26/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.3315 - accuracy: 0.9706 - val_loss: 0.3598 - val_accuracy: 1.0000
# Epoch 27/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.3145 - accuracy: 0.9706 - val_loss: 0.3424 - val_accuracy: 1.0000
# Epoch 28/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2988 - accuracy: 0.9559 - val_loss: 0.3263 - val_accuracy: 1.0000
# Epoch 29/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2836 - accuracy: 0.9559 - val_loss: 0.3118 - val_accuracy: 1.0000
# Epoch 30/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2701 - accuracy: 0.9559 - val_loss: 0.2992 - val_accuracy: 1.0000
# Epoch 31/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2561 - accuracy: 0.9559 - val_loss: 0.2869 - val_accuracy: 1.0000
# Epoch 32/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2427 - accuracy: 0.9706 - val_loss: 0.2787 - val_accuracy: 1.0000
# Epoch 33/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2295 - accuracy: 0.9706 - val_loss: 0.2681 - val_accuracy: 1.0000
# Epoch 34/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.2183 - accuracy: 0.9706 - val_loss: 0.2576 - val_accuracy: 1.0000
# Epoch 35/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.2069 - accuracy: 0.9706 - val_loss: 0.2471 - val_accuracy: 1.0000
# Epoch 36/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1972 - accuracy: 0.9706 - val_loss: 0.2424 - val_accuracy: 1.0000
# Epoch 37/50
# 3/3 [==============================] - 0s 9ms/step - loss: 0.1881 - accuracy: 0.9853 - val_loss: 0.2359 - val_accuracy: 1.0000
# Epoch 38/50
# 3/3 [==============================] - 0s 10ms/step - loss: 0.1792 - accuracy: 0.9853 - val_loss: 0.2282 - val_accuracy: 1.0000
# Epoch 39/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1712 - accuracy: 0.9853 - val_loss: 0.2182 - val_accuracy: 1.0000
# Epoch 40/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1625 - accuracy: 0.9853 - val_loss: 0.2037 - val_accuracy: 1.0000
# Epoch 41/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1540 - accuracy: 0.9853 - val_loss: 0.1858 - val_accuracy: 1.0000
# Epoch 42/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1467 - accuracy: 0.9853 - val_loss: 0.1724 - val_accuracy: 1.0000
# Epoch 43/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1406 - accuracy: 0.9853 - val_loss: 0.1615 - val_accuracy: 1.0000
# Epoch 44/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1363 - accuracy: 0.9853 - val_loss: 0.1545 - val_accuracy: 1.0000
# Epoch 45/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1306 - accuracy: 0.9853 - val_loss: 0.1521 - val_accuracy: 1.0000
# Epoch 46/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1252 - accuracy: 0.9853 - val_loss: 0.1512 - val_accuracy: 1.0000
# Epoch 47/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1192 - accuracy: 0.9853 - val_loss: 0.1507 - val_accuracy: 1.0000
# Epoch 48/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1152 - accuracy: 0.9853 - val_loss: 0.1505 - val_accuracy: 1.0000
# Epoch 49/50
# 3/3 [==============================] - 0s 16ms/step - loss: 0.1114 - accuracy: 0.9853 - val_loss: 0.1491 - val_accuracy: 1.0000
# Epoch 50/50
# 3/3 [==============================] - 0s 15ms/step - loss: 0.1080 - accuracy: 0.9853 - val_loss: 0.1454 - val_accuracy: 1.0000

# %%
# Preparar datos de predicción y escalarlos
X_pred = FusionData[['Ejex_NH', 'Ejex_SH', 'Ejex_OH', 'Ejey_OHb', 'Log_12_25']]
X_pred_scaled = scaler.transform(X_pred)

# Predecir las etiquetas para los datos restantes
y_pred_categorical = model.predict(X_pred_scaled)
# Out:
# 40/40 [==============================] - 0s 897us/step

# %%
# Convertir las predicciones a etiquetas
y_pred_encoded = np.argmax(y_pred_categorical, axis=1)
y_pred_labels = label_encoder.inverse_transform(y_pred_encoded)

# %%
# Agregar las etiquetas predichas al DataFrame original
FusionData['Predicciones'] = y_pred_labels
FusionData[0:5]
# Out:
#      ra_sdss  dec_sdss    ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.51395  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.23460  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.70757  0.617749  314283887213701120  0.025391
# 3  170.82587 -0.922475  170.82668 -0.921258  315274540949202944  0.008394
# 4  169.38707 -0.187502  169.38559 -0.186404  315334739210823680  0.040338
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  rat_60_100  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    0.342175
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...    0.811881
# 2      528.2295    139.90980       34.019120       62.50361  ...    0.418994
# 3      998.6539    263.62670      358.444700       54.00912  ...    0.431095
# 4      520.6220     74.79313       28.152840       74.78139  ...    0.323810
#
#    Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH Log_12_25     EtiqRef  EtiqRef60%  \
# 0 -2.275763 -1.065383 -1.694790 -5.024607 -0.356675         NaN         NaN
# 1  0.625129 -1.488608 -1.481473 -4.039606  0.441833         NaN         NaN
# 2 -1.414075 -0.743963 -1.261980 -3.489259 -0.693147         NaN         NaN
# 3  0.307240 -1.526911 -1.179064 -3.498782 -0.524524         NaN         NaN
# 4 -0.977078 -0.550111 -1.223666 -2.962311 -0.205852  Infrarroja         NaN
#
#    EtiqRef40%  Predicciones
# 0         NaN    Infrarroja
# 1         NaN    Infrarroja
# 2         NaN    Infrarroja
# 3         NaN    Infrarroja
# 4  Infrarroja    Infrarroja
#
# [5 rows x 33 columns]

# %%
# Cuantos infrarrojas, Seyfert y LINER fueron clasificadas en ClusterN2D:
conteoPredicciones = FusionData['Predicciones'].value_counts()
conteoPredicciones
# Out:
# Infrarroja    1086
# Seyfert        117
# LINER           66
# Name: Predicciones, dtype: int64

# %% [markdown]
# ## 2. Medición de exactitud con Frecuencia cruzada

# %%
tabla_frecuencias = pd.crosstab(FusionData['EtiqRef40%'], FusionData['Predicciones'], margins=True, margins_name="Total")
tabla_frecuencias
# Out:
# Predicciones  Infrarroja  LINER  Seyfert  Total
# EtiqRef40%
# Infrarroja            32      0        0     32
# LINER                  0      8        0      8
# Seyfert                1      2       30     33
# Total                 33     10       30     73

# %%
# Para obtener las cantidades de coincidencias específicas, puedes acceder a los valores en la tabla
coincidencias_infrarroja = tabla_frecuencias.loc['Infrarroja', 'Infrarroja']
coincidencias_seyfert = tabla_frecuencias.loc['Seyfert', 'Seyfert']
coincidencias_liner = tabla_frecuencias.loc['LINER', 'LINER']

print("Coincidencias Infrarroja:", coincidencias_infrarroja)
print("Coincidencias Seyfert:", coincidencias_seyfert)
print("Coincidencias LINER:", coincidencias_liner)
# Out:
# Coincidencias Infrarroja: 32
# Coincidencias Seyfert: 30
# Coincidencias LINER: 8

# %% [markdown]
# ### Cálculos

# %%
# Calcula los verdaderos positivos, falsos positivos, falsos negativos y verdaderos negativos
verdaderos_positivos = tabla_frecuencias.loc['Infrarroja', 'Infrarroja']
falsos_positivos = tabla_frecuencias.loc['Total', 'Infrarroja'] - verdaderos_positivos
falsos_negativos = tabla_frecuencias.loc['Infrarroja', 'Total'] - verdaderos_positivos
verdaderos_negativos = tabla_frecuencias.loc['Total', 'Total'] - verdaderos_positivos - falsos_positivos - falsos_negativos

# %%
# Calcula la Precisión
precision = verdaderos_positivos / (verdaderos_positivos + falsos_positivos)
# Calcula la Sensibilidad
sensibilidad = verdaderos_positivos / (verdaderos_positivos + falsos_negativos)

# %%
# Calcula los Falsos Positivos y Falsos Negativos
falsos_positivos = falsos_positivos / (falsos_positivos + verdaderos_negativos)
falsos_negativos = falsos_negativos / (falsos_negativos + verdaderos_positivos)

# %%
# Imprime los resultados
print("Precisión:", precision)
print("Sensibilidad:", sensibilidad)
print("Falsos Positivos:", falsos_positivos)
print("Falsos Negativos:", falsos_negativos)
# Out:
# Precisión: 0.9696969696969697
# Sensibilidad: 1.0
# Falsos Positivos: 0.024390243902439025
# Falsos Negativos: 0.0

# %% [markdown]
# # Conclusiones:

# %% [markdown]
# ## 2. Medición: 100%
