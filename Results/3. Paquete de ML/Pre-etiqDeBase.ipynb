# %% [markdown]
# **Objetivo:**
# Dado el codigo: Base1269gal y 4.3 Etiquetado Mix de (500.000 galaxias):
# Crear una tabla de 1.269 Galaxias con las etiquetas que se crucen.

# %% [markdown]
# ## Datos de Base1269gal

# %%
# %run "C:\Users\Cristina Quiazúa M\Desktop\MyBPT\Results\3. Paquete de ML\Base1269gal.ipynb"
# Out:
# Could not import regions, which is required for some of the functionalities of this module.
# Valores duplicados en la columna 'ra': [132.58559 179.51375 185.48906 351.8132 ]
# Índices de los valores duplicados en la columna 'ra': Int64Index([4105, 5929, 6215, 11228], dtype='int64')
# Índices de TODAS las ocurrencias de valores duplicados en la columna 'ra': Int64Index([4100, 4105, 5928, 5929, 6213, 6215, 11227, 11228], dtype='int64')
# C:\ProgramData\Anaconda33\lib\site-packages\astroquery\sdss\core.py:874: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   arr = np.atleast_1d(np.genfromtxt(io.BytesIO(response.content),
# Número de valores únicos: 293697
# Número de valores repetidos 1 vez: 14895
# Número de valores repetidos 2 veces: 1239
# Número de valores repetidos 3 veces: 211
# Número de valores repetidos 4 veces: 242
# Número de valores repetidos 5 veces: 45
# ...

# %%
FusionData[0:3]
# Out:
#      ra_sdss  dec_sdss     ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.513947  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.234604  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.707565  0.617749  314283887213701120  0.025391
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  fnu_60  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    5.16
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...    0.82
# 2      528.2295    139.90980       34.019120       62.50361  ...    0.75
#
#    fnu_100  rat_12_25  rat_25_60 rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH  \
# 0    15.08   0.700000   0.096899   0.342175 -2.275763 -1.065383 -1.694790
# 1     1.01   1.555556   0.329268   0.811881  0.625129 -1.488608 -1.481473
# 2     1.79   0.500000   0.666667   0.418994 -1.414075 -0.743963 -1.261980
#
#     Ejex_OH  Log_12_25
# 0 -5.024607  -0.356675
# ...

# %%
len(FusionData)
# Out:
# 1269

# %%
## Datos de 4.3 Etiquetado Mix

# %%
# %run "C:\Users\Cristina Quiazúa M\Desktop\MyBPT\SDSS\With500MD\4.3 Etiquetado Mix.ipynb"
# Out:
# Valores duplicados en la columna 'ra': [132.58559 179.51375 185.48906 351.8132 ]
# Índices de los valores duplicados en la columna 'ra': Int64Index([4105, 5929, 6215, 11228], dtype='int64')
# Índices de TODAS las ocurrencias de valores duplicados en la columna 'ra': Int64Index([4100, 4105, 5928, 5929, 6213, 6215, 11227, 11228], dtype='int64')
# C:\ProgramData\Anaconda33\lib\site-packages\astroquery\sdss\core.py:874: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   arr = np.atleast_1d(np.genfromtxt(io.BytesIO(response.content),
# Número de valores únicos: 293697
# Número de valores repetidos 1 vez: 14895
# Número de valores repetidos 2 veces: 1239
# Número de valores repetidos 3 veces: 211
# Número de valores repetidos 4 veces: 242
# Número de valores repetidos 5 veces: 45
# Número de valores repetidos 6 veces: 14
# Número de valores repetidos 7 veces: 3
# ...

# %%
dfref[0:3]
# Out:
#                   specobjid          ra        dec         z  h_alpha_flux  \
# 77221    904201567027095552   47.312554   1.162262  0.180198      166.8196
# 223501  2185510864210126848  142.604790  31.738383  0.111991      134.5694
# 223376  2185385794762467328  142.707660  30.870949  0.059067      256.4268
#
#         h_beta_flux  oiii_5007_flux  nii_6548_flux  nii_6584_flux  \
# 77221      43.78514       60.582780       10.67823       32.20801
# 223501     33.25322        4.560243       15.62031       47.11446
# 223376     76.09786       76.059970       19.10148       57.61448
#
#         sii_6717_flux  sii_6731_flux  oi_6300_flux        subclass  Ejey_OHB  \
# 77221        29.88691       19.03142      5.540886    b'STARBURST'  0.324716
# 223501       26.26056       22.80412      2.745854  b'STARFORMING' -1.986776
# 223376       55.22266       35.56358      9.270071  b'STARFORMING' -0.000498
#
#          Ejex_NH   Ejex_SH   Ejex_OH    ETIQUETA     Coin100     EtiqRef
# ...

# %%
len(dfref)
# Out:
# 36478

# %%
type(dfref)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ## Agregar la Fila “EtiqRef”: 100% Seyfert e infrarroja + 66.7% de LINER, Ojo se puede ampliar mas en Infrarroja, pero esta seria solo una muestra:

# %%
# Fusionar los DataFrames utilizando la columna "ra_sdss" en "FusionData" y "ra" en "dfref"
FusionData = pd.merge(FusionData, dfref[['ra', 'EtiqRef']], left_on='ra_sdss', right_on='ra', how='left')

# Eliminar la columna redundante "ra" después de la fusión
FusionData.drop('ra', axis=1, inplace=True)

# %%
FusionData[0:3]
# Out:
#      ra_sdss  dec_sdss     ra_iras  dec_iras           specobjid         z  \
# 0  145.51241  0.339171  145.513947  0.337522  299595780317014016  0.006379
# 1  167.23240  0.444804  167.234604  0.444661  313129123717343232  0.012902
# 2  169.70646  0.619308  169.707565  0.617749  314283887213701120  0.025391
#
#    h_alpha_flux  h_beta_flux  oiii_5007_flux  nii_6548_flux  ...  fnu_100  \
# 0      153.8173     35.59267        3.656026       13.19764  ...    15.08
# 1    10285.9400   3250.79100     6074.062000      578.00410  ...     1.01
# 2      528.2295    139.90980       34.019120       62.50361  ...     1.79
#
#    rat_12_25  rat_25_60  rat_60_100  Ejey_OHb   Ejex_NH   Ejex_SH   Ejex_OH  \
# 0   0.700000   0.096899    0.342175 -2.275763 -1.065383 -1.694790 -5.024607
# 1   1.555556   0.329268    0.811881  0.625129 -1.488608 -1.481473 -4.039606
# 2   0.500000   0.666667    0.418994 -1.414075 -0.743963 -1.261980 -3.489259
#
#    Log_12_25  EtiqRef
# 0  -0.356675      NaN
# ...

# %%
conteoEtiqRef = FusionData['EtiqRef'].value_counts()
conteoEtiqRef
# Out:
# Infrarroja    75
# Seyfert       60
# LINER         23
# Name: EtiqRef, dtype: int64

# %%
a= 75+60+23
a
# Out:
# 158

# %% [markdown]
# ## Concluisones:
# De la base de 1.269 Galaxias tengo Pre-etiquetadas 158, que corresponden al 12.45% de los datos.
# Si es necesario se puede ampliar un poco más el porcentaje ampliando las Infrarrojas al total. Para efectos de una muestra de al rededor del 10% de preetiquetado por ahora se deja así.

# %%
# EXPORTANDO A CSV

# FusionData.to_csv('Mydata.csv', index=False)

# %%
# ver similitudes entre las dadas por SDSS y las mias (EtiqRef) #Se pueden hasta la 60
tabla = FusionData[['class', 'subclass', 'EtiqRef']].head(5)
tabla
# Out:
#        class        subclass     EtiqRef
# 0  b'GALAXY'    b'STARBURST'         NaN
# 1  b'GALAXY'    b'STARBURST'         NaN
# 2  b'GALAXY'  b'STARFORMING'         NaN
# 3  b'GALAXY'    b'STARBURST'         NaN
# 4  b'GALAXY'  b'STARFORMING'  Infrarroja
