# %% [markdown]
# **Objetivo:**
#
# Dados las gráficas 1.2 de 20.000 galaxias con curvas según: The Host Galaxies and Classification of Active Galactic Nuclei - 2006 y Z < 0.8, pre etiquetar entre 4 grupos, usando la curva "b" del diagrama BPT: SII
#
# Analizando los datos de ejex_SH, ejey_OHb
#
# **Galaxias: Infrarroja, Seyfert o LINER**

# %% [markdown]
# **PROCEDIMIENTO:**
#     **1.1** Dados iniciales.
#     **1.2** Para SII.
#
#         a. Infrarroja = Abajo de Kewley.
#         aa. Pre-Etiquetado Infrarrojas
#
#         b. Gráfico diferente de Infrarrojas.
#
#         c. Seyfert = Arriba de la línea Seyfert-LINER.
#         cc. Pre-Etiquetado gráfico Seyfert
#
#         d. LINER = Abajo de la línea Seyfert-LINER.
#         dd. Pre-Etiquetado gráfico LINER
#
#
#     **1.3** Etiquetas MANERA DEDUCTIVA.
#     1.3.1 Comprobación de cantidades.
#     1.3.2 Solucion de cantidades.
#     1.3.3 Matriz SII Deductiva.
#     1.3.4 Graficas de SII Deductiva.

# %% [markdown]
# ## 1.1 Dados iniciales.

# %%
# %run "C:\Users\Cristina Quiazúa M\Desktop\MyBPT\SDSS\With20MD_AA\1.3 GrafConDataIgualesYCurv NoRepetidas.ipynb"
# Out:
# Could not import regions, which is required for some of the functionalities of this module.
# Valores duplicados en la columna 'ra': [132.58559 179.51375 185.48906 351.8132 ]
# Índices de los valores duplicados en la columna 'ra': Int64Index([4105, 5929, 6215, 11228], dtype='int64')
# Índices de TODAS las ocurrencias de valores duplicados en la columna 'ra': Int64Index([4100, 4105, 5928, 5929, 6213, 6215, 11227, 11228], dtype='int64')
# C:\ProgramData\Anaconda33\lib\site-packages\astroquery\sdss\core.py:874: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   arr = np.atleast_1d(np.genfromtxt(io.BytesIO(response.content),
# Número de valores únicos: 293697
# Número de valores repetidos 1 vez: 14895
# Número de valores repetidos 2 veces: 1239
# Número de valores repetidos 3 veces: 211
# Número de valores repetidos 4 veces: 242
# Número de valores repetidos 5 veces: 45
# Número de valores repetidos 6 veces: 14
# Número de valores repetidos 7 veces: 3
# Número de valores repetidos 8 veces: 0
# Número de valores repetidos 9 veces: 0
# Número de valores repetidos 10 veces: 0
# Valores duplicados en la columna 'ra': [146.9639  146.94999 146.63167 ... 257.38367 258.13561 257.98823]
# Índices de los valores duplicados en la columna 'ra': Int64Index([     5,      7,      8,      9,     10,     12,     15,     18,
#                 20,     22,
#             ...
#             329098, 329099, 329100, 329102, 329103, 329116, 329285, 329438,
#             329439, 329576],
#            dtype='int64', length=19304)
# Índices donde el valor de 'ra' es igual a 145.51241: Int64Index([167, 170], dtype='int64')

# %%
len(data)
# Out:
# 20000

# %%
#Convertir pandas.core.frame.DataFrame a astropy.table.table.Table
astropy_table = Table.from_pandas(data)

# %%
data = astropy_table

# %% [markdown]
# ## Razones

# %%
ejey_OHb=np.log((data['oiii_5007_flux'])/(data['h_beta_flux']))

ejex_NH=np.log((data['nii_6548_flux']+data['nii_6584_flux'])/data['h_alpha_flux'])
ejex_SH=np.log((data['sii_6717_flux']+data['sii_6731_flux'])/data['h_alpha_flux'])
ejex_OH=np.log((data['oi_6300_flux'])/(data['h_alpha_flux']))

# %%
# Ingresar las columnas de razones a la data.
data.add_column(ejey_OHb, name='Ejey_OHB')
data.add_column(ejex_NH, name='Ejex_NH')
data.add_column(ejex_SH, name='Ejex_SH')
data.add_column(ejex_OH, name='Ejex_OH')

# %%
data[1:5]
# Out:
# <Table length=4>
#      specobjid          ra    ...       Ejex_SH              Ejex_OH
#        int64         float64  ...       float64              float64
# ------------------- --------- ... -------------------- -------------------
# 3104165492441507840 210.66121 ...  -1.3201851645522702 -3.2065998546735357
# 1517815380746201088 214.81139 ...  -0.8327896492215614 -2.0166022729357027
# 2800244799460894720 165.09742 ... -0.27746988015478935  -1.543232626364033
# 2362234269872449536 172.63366 ...  -0.9815413830917822  -4.417493729916491

# %% [markdown]
# ## 1.2 Para SII.
#
#     a. Infrarroja = Abajo de Kewley.
#     aa. Pre-Etiquetado Infrarrojas
#
#     b. Gráfico diferente de Infrarrojas.
#
#     c. Seyfert = Arriba de la línea Seyfert-LINER.
#     cc. Pre-Etiquetado gráfico Seyfert
#
#     d. LINER = Abajo de la línea Seyfert-LINER.
#     dd. Pre-Etiquetado gráfico LINER

# %% [markdown]
# ### a. Infrarroja = Abajo de Kewley.

# %%
# Convertir la tabla de datos en un DataFrame de Pandas
df = data.to_pandas()

# %%
# Filtrar los datos que están por debajo de la línea de Kewley y tienen log [SII] /Hα <= 0.3
filtrados = df.query("Ejey_OHB <= (1.3 + (0.72 / (Ejex_SH - 0.32))) and Ejex_SH <= 0.3")

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(filtrados["Ejex_SH"], filtrados["Ejey_OHB"], marker="+", color="olivedrab")

ax.set_xlim(-4, 1.5)
ax.set_ylim(-4, 4)
plt.title('Pre-Etiquetado Infrarrojas')
plt.ylabel('log [O III]/ Hβ')
plt.xlabel('log [SII] /Hα')

# Kewley
x1 = np.linspace(-4,0.3) 
y1 = 1.30 + (0.72/(x1-0.32))
plt.plot(x1, y1, '-' , color='red', lw=2, label= 'Kewley')

# %% [markdown]
# ### aa. Pre-Etiquetado Infrarrojas

# %%
# Agregar una nueva columna "Infrarroja" al DataFrame con los valores "1" o "0"
df["Infrarroja"] = df.apply(lambda row: 1 if (row["Ejey_OHB"] <= (1.3 + (0.72 / (row["Ejex_SH"] - 0.32)))) and (row["Ejex_SH"] <= 0.3) else "0", axis=1)

# %%
df[10:15]
# Out:
#               specobjid         ra        dec         z  h_alpha_flux  \
# 10  1062982871699974144  154.60474  46.404902  0.123735      704.3109
# 11  2015417523125643264  191.01244   6.287413  0.165674      121.6849
# 12   936786419555264512  138.02905  43.717246  0.060355      702.1112
# 13  2477132142425958400  242.77580  17.151947  0.186033      194.4646
# 14  2519863292986419200  191.27810  28.361928  0.091532      613.0876
#
#     h_beta_flux  oiii_5007_flux  nii_6548_flux  nii_6584_flux  sii_6717_flux  \
# 10    199.27100      381.741400       37.28394      112.45700       93.35062
# 11     24.67171       12.619070       16.87188       50.88948       22.67010
# 12    205.18500      451.900900       31.21945       94.16506      115.89880
# 13     31.70225        9.568507       28.69942       86.56406       10.04644
# 14    173.04620      263.718800       29.67182       89.49706       76.22830
#
#     sii_6731_flux  oi_6300_flux      class        subclass  Ejey_OHB  \
# 10       67.65799     15.896410  b'GALAXY'    b'STARBURST'  0.650078
# 11       18.02446      7.996521  b'GALAXY'  b'STARFORMING' -0.670448
# 12       81.89982     24.297660  b'GALAXY'    b'STARBURST'  0.789551
# 13       19.21068      6.562323  b'GALAXY'  b'STARFORMING' -1.197910
# 14       59.68037      9.477549  b'GALAXY'    b'STARBURST'  0.421325
#
#      Ejex_NH   Ejex_SH   Ejex_OH Infrarroja
# 10 -1.548313 -1.475762 -3.791127          1
# 11 -0.585443 -1.095340 -2.722428          1
# 12 -1.722707 -1.266842 -3.363712          1
# 13 -0.523030 -1.894127 -3.388905          1
# 14 -1.637966 -1.506525 -4.169582          1

# %%
conteo_i = df["Infrarroja"].value_counts()[1]
conteo_i
# Out:
# 17790

# %%
conteo_0 = df["Infrarroja"].value_counts()["0"]
conteo_0
# Out:
# 2210

# %%
suma=17891+2109
suma
# Out:
# 20000

# %% [markdown]
# ### b. Gráfico diferente de Infrarrojas.

# %%
# Calcular los índices de datos que no están debajo de la curva de Kewley
indices_no_kewley = ~((df["Ejey_OHB"] <= (1.3 + (0.72 / (df["Ejex_SH"] - 0.32)))) & (df["Ejex_SH"] <= 0.3))

# Seleccionar los datos que no están debajo de la curva de Kewley
datos_no_kewley = df[indices_no_kewley]

# %%
# Crear una figura y un subárea de gráfico
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(datos_no_kewley["Ejex_SH"], datos_no_kewley["Ejey_OHB"], marker="+", color="limegreen")

ax.set_xlim(-4, 2)
ax.set_ylim(-4, 4)
plt.title('Diferente de Infrarrojas')
plt.ylabel('log [O III]/ Hβ')
plt.xlabel('log [SII] /Hα')

# Trazar la línea de Kewley
x1 = np.linspace(-4, 0.3) 
y1 = 1.30 + (0.72 / (x1 - 0.32))
plt.plot(x1, y1, '-', color='red', lw=2, label='Kewley')

# Seyfert-LINER
x2 = np.linspace(-0.32,4.0)
y2 = 0.76 + (1.89*x2)
plt.plot(x2, y2, '-.', color='green', lw=2, label='Seyfert-LINER')

# %% [markdown]
# ### c. Seyfert = Arriba de la línea Seyfert-LINER

# %%
# Calcular los índices de datos que están encima de la curva Seyfert-LINER y arriba de la curva Kewley
IndSeyfert = (df["Ejey_OHB"] > (0.76 + (1.89 * df["Ejex_SH"]))) & (df["Ejey_OHB"] > (1.3 + (0.72 / (df["Ejex_SH"] - 0.33)))) 

# Seleccionar los datos que están al lado derecho de la curva Seyfert-LINER y arriba de la curva Kewley
DatSeyfert = df[IndSeyfert]

# %%
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(DatSeyfert["Ejex_SH"], DatSeyfert["Ejey_OHB"], marker="+", color="yellowgreen")
ax.set_xlim(-4, 2)
ax.set_ylim(-4, 4)
plt.title('Pre-Etiquetado Seyferts')
plt.ylabel('log [O III]/ Hβ')
plt.xlabel('log [SII] /Hα')

# Kewley
x1 = np.linspace(-4, 0.3) 
y1 = 1.30 + (0.72 / (x1 - 0.32))
plt.plot(x1, y1, '-', color='red', lw=2, label='Kewley')

#Seyfert-LINER
x2 = np.linspace(-0.32, 4.0)
y2 = 0.76 + (1.89*x2)
plt.plot(x2, y2, '-.', color='green', lw=2, label='Seyfert-LINER')

# %% [markdown]
# ### cc. Pre-Etiquetado gráfico Seyferts

# %%
# Crear una columna "Seyfert" llena de ceros en el DataFrame
df['Seyfert'] = 0

# Identificar las filas que cumplen las condiciones del código y establecer "Seyfert" en 1
df.loc[IndSeyfert, 'Seyfert'] = 1

# %%
conteo_s = df["Seyfert"].value_counts()[1]
conteo_s
# Out:
# 1873

# %%
df[80:85]
# Out:
#               specobjid         ra        dec         z  h_alpha_flux  \
# 80  1387189820031264768  186.68453   9.048442  0.023137    2363.87500
# 81  3090711038866253824  212.00761  16.120834  0.129784     155.23700
# 82  3089620049141458944  211.15857  16.280142  0.069339     153.59130
# 83  1972658881972692992  167.75680  13.300534  0.092625     351.39910
# 84  1155317933115729920  319.03925   1.074412  0.226192      61.08723
#
#     h_beta_flux  oiii_5007_flux  nii_6548_flux  nii_6584_flux  sii_6717_flux  \
# 80    565.29020       84.477130     391.984800     1182.31700      283.75710
# 81     40.56261       10.516620      17.625520       53.16264       30.70328
# 82     31.75509       13.223350      17.706320       53.40635       33.70737
# 83    106.55590       73.805500      29.925610       90.26255       71.94416
# 84     11.74083        5.886059       9.170021       27.65890       14.95667
#
#     sii_6731_flux  oi_6300_flux      class        subclass  Ejey_OHB  \
# 80      289.23190     27.164050  b'GALAXY'    b'STARBURST' -1.900858
# 81       17.11654      5.646622  b'GALAXY'  b'STARFORMING' -1.349890
# 82       21.75994      6.968799  b'GALAXY'  b'STARFORMING' -0.876069
# 83       48.14748     10.927890  b'GALAXY'    b'STARBURST' -0.367236
# 84       11.63641      0.180403  b'GALAXY'  b'STARFORMING' -0.690486
#
#      Ejex_NH   Ejex_SH   Ejex_OH Infrarroja  Seyfert
# 80 -0.406490 -1.417191 -4.466163          1        0
# 81 -0.785261 -1.177513 -3.313895          1        0
# 82 -0.770030 -1.018501 -3.092852          1        0
# 83 -1.072864 -1.073667 -3.470604          1        0
# 84 -0.506019 -0.831652 -5.824867          1        0

# %% [markdown]
# ### d. LINER = Abajo de la línea Seyfert-LINER

# %%
# Calcular los índices de datos que no están debajo de la curva de Kewley
indices_no_kewley = ~((df["Ejey_OHB"] <= (1.3 + (0.72 / (df["Ejex_SH"] - 0.32)))) & (df["Ejex_SH"] <= 0.3))

# %%
# Calcular los índices de datos que están abajo de la curva Seyfert-LINER
PreIndLiner = df["Ejey_OHB"] < (0.76 + (1.89 * df["Ejex_SH"]))

# %%
# Combinar ambos conjuntos de índices para obtener los datos que están a la izquierda de Seyfert-LINER y no debajo de Kewley
IndLiner = indices_no_kewley & PreIndLiner

# %%
# Seleccionar los datos que cumplen las condiciones
Liner = df[IndLiner]

# %%
# Crear una figura y un subárea de gráfico
fig = plt.figure()
ax = fig.add_subplot()

ax.scatter(Liner["Ejex_SH"], Liner["Ejey_OHB"], marker="+", color="gold")

ax.set_xlim(-4, 2)
ax.set_ylim(-4, 4)
plt.title('Pre-Etiquetado LINER')
plt.ylabel('log [O III]/ Hβ')
plt.xlabel('log [SII] /Hα')

# Trazar la línea de Kewley
x1 = np.linspace(-4, 0.3) 
y1 = 1.30 + (0.72 / (x1 - 0.32))
plt.plot(x1, y1, '-', color='red', lw=2, label='Kewley')

# Trazar la línea de Seyfert-LINER
x2 = np.linspace(-0.32, 4.0)
y2 = 0.76 + (1.89 * x2)
plt.plot(x2, y2, '-.', color='green', lw=2, label='Seyfert-LINER')

plt.legend()
plt.show()

# %% [markdown]
# ### dd. Pre-Etiquetado gráfico LINER

# %%
# Crear una columna "LINER" llena de ceros en el DataFrame
df['LINER'] = 0

# Identificar las filas que cumplen las condiciones del código y establecer "LINER" en 1
df.loc[IndLiner, 'LINER'] = 1

# %%
df[45:55]
# Out:
#               specobjid          ra        dec         z  h_alpha_flux  \
# 45  2251806194513504256  191.788230  37.952852  0.115901     253.99590
# 46   453835000626833408   28.503586   0.278284  0.080787     270.88830
# 47  1584219007794309120  244.296010  28.279814  0.161493     128.05680
# 48  3097398268787714048  225.495090  13.179458  0.069548     227.64040
# 49  1141804937710168064  174.020480  54.920502  0.074715      52.38829
# 50  1182221061236746240  229.052370  45.151863  0.062543     102.53500
# 51  2564863821722183680  129.474710  16.931870  0.117663     139.23920
# 52  1319619608293959680  246.358960  39.508135  0.031581     898.85840
# 53  1861153562109700096  236.268820  27.635878  0.075171     959.87260
# 54  1858897087828092928  231.586700  29.274290  0.066267      34.02571
#
#     h_beta_flux  oiii_5007_flux  nii_6548_flux  nii_6584_flux  sii_6717_flux  \
# 45    55.084670       23.018510       39.05176      117.78910       58.28876
# 46    80.564420       61.231600       21.62913       65.23846       52.80046
# 47    28.414790        9.650946       13.31531       40.16204       17.96926
# 48    71.733700       32.308770       21.18504       63.89896       50.68618
# 49     9.515209        6.470725       11.83767       35.70516       11.12443
# 50    26.821470       10.796970       14.48385       43.68665       18.30188
# 51    29.179770        6.614156       14.63224       44.13422       18.68152
# 52   239.133300       62.080430      101.02780      304.72310      160.42450
# 53   140.259700       29.087390      140.41960      423.53790      114.43400
# 54    16.132070       17.176560        4.81208       14.51435       14.26806
#
#     ...  oi_6300_flux      class        subclass  Ejey_OHB   Ejex_NH  \
# 45  ...      9.997869  b'GALAXY'  b'STARFORMING' -0.872573 -0.482086
# 46  ...      9.029892  b'GALAXY'    b'STARBURST' -0.274394 -1.137322
# 47  ...      5.679413  b'GALAXY'  b'STARFORMING' -1.079854 -0.873216
# 48  ...      6.617966  b'GALAXY'  b'STARFORMING' -0.797622 -0.984128
# 49  ...      3.052242  b'GALAXY'  b'STARFORMING' -0.385603 -0.097052
# 50  ...      5.753649  b'GALAXY'  b'STARFORMING' -0.909937 -0.566826
# 51  ...      5.027533  b'GALAXY'  b'STARFORMING' -1.484263 -0.862622
# 52  ...     20.408440  b'GALAXY'    b'STARBURST' -1.348590 -0.795386
# 53  ...     19.450470  b'GALAXY'  b'STARFORMING' -1.573191 -0.531822
# 54  ...      4.408963  b'GALAXY'  b'STARFORMING'  0.062736 -0.565643
#
#      Ejex_SH   Ejex_OH  Infrarroja Seyfert  LINER
# 45 -0.977704 -3.234946           1       0      0
# 46 -1.180504 -3.401166           1       0      0
# 47 -1.527660 -3.115626           1       0      0
# 48 -0.956714 -3.537979           1       0      0
# 49 -1.065971 -2.842807           1       0      0
# 50 -1.263300 -2.880370           1       0      0
# 51 -1.498210 -3.321264           1       0      0
# 52 -1.185779 -3.785177           1       0      0
# 53 -1.527646 -3.898929           1       0      0
# 54 -0.529997 -2.043477           1       0      0
#
# [10 rows x 21 columns]

# %%
conteo_L = df["LINER"].value_counts()[1]
conteo_L
# Out:
# 321

# %% [markdown]
# ## 1.3 Etiquetas MANERA DEDUCTIVA.

# %% [markdown]
# 1.3.1 Comprobación de cantidades.
# 1.3.2 Solucion de cantidades.
# 1.3.3 Matriz SII Deductiva.
# 1.3.4 Graficas de SII Deductiva.

# %% [markdown]
# ### 1.3.1 Comprobación de cantidades.

# %%
conteo_i = df["Infrarroja"].value_counts()[1]
conteo_i
# Out:
# 17790

# %%
conteo_s = df["Seyfert"].value_counts()[1]
conteo_s
# Out:
# 1873

# %%
conteo_L = df["LINER"].value_counts()[1]
conteo_L
# Out:
# 321

# %%
Suma= conteo_i + conteo_s + conteo_L
Suma
# Out:
# 19984

# %% [markdown]
# ### 1.3.2 Solucion de cantidades.

# %%
SumaA = 20000- Suma
SumaA
# Existen 12 Galaxias que no fueron identificadas, seguiran identificadas como 0.
# Out:
# 16

# %% [markdown]
# ### 1.3.3 Matriz SII Deductiva.

# %%
# Obtener la lista de columnas que se deben evaluar
columnas_evaluar = ["Infrarroja", "Seyfert", "LINER"]

# %%
# Crear la columna "PreEtiqueta" con los valores correspondientes, si no es 1, entonces: es combinada.
def obtener_pre_etiqueta(row):
    etiquetas = []
    for etiqueta in columnas_evaluar:
        if row[etiqueta] == 1:
            etiquetas.append(etiqueta)
    if len(etiquetas) == 1:
        return etiquetas[0]
    else:
        return "N/I"

# %%
df["PreEtiquetaSII"] = df.apply(obtener_pre_etiqueta, axis=1)
df[45:55]
# Out:
#               specobjid          ra        dec         z  h_alpha_flux  \
# 45  2251806194513504256  191.788230  37.952852  0.115901     253.99590
# 46   453835000626833408   28.503586   0.278284  0.080787     270.88830
# 47  1584219007794309120  244.296010  28.279814  0.161493     128.05680
# 48  3097398268787714048  225.495090  13.179458  0.069548     227.64040
# 49  1141804937710168064  174.020480  54.920502  0.074715      52.38829
# 50  1182221061236746240  229.052370  45.151863  0.062543     102.53500
# 51  2564863821722183680  129.474710  16.931870  0.117663     139.23920
# 52  1319619608293959680  246.358960  39.508135  0.031581     898.85840
# 53  1861153562109700096  236.268820  27.635878  0.075171     959.87260
# 54  1858897087828092928  231.586700  29.274290  0.066267      34.02571
#
#     h_beta_flux  oiii_5007_flux  nii_6548_flux  nii_6584_flux  sii_6717_flux  \
# 45    55.084670       23.018510       39.05176      117.78910       58.28876
# 46    80.564420       61.231600       21.62913       65.23846       52.80046
# 47    28.414790        9.650946       13.31531       40.16204       17.96926
# 48    71.733700       32.308770       21.18504       63.89896       50.68618
# 49     9.515209        6.470725       11.83767       35.70516       11.12443
# 50    26.821470       10.796970       14.48385       43.68665       18.30188
# 51    29.179770        6.614156       14.63224       44.13422       18.68152
# 52   239.133300       62.080430      101.02780      304.72310      160.42450
# 53   140.259700       29.087390      140.41960      423.53790      114.43400
# 54    16.132070       17.176560        4.81208       14.51435       14.26806
#
#     ...      class        subclass  Ejey_OHB   Ejex_NH   Ejex_SH   Ejex_OH  \
# 45  ...  b'GALAXY'  b'STARFORMING' -0.872573 -0.482086 -0.977704 -3.234946
# 46  ...  b'GALAXY'    b'STARBURST' -0.274394 -1.137322 -1.180504 -3.401166
# 47  ...  b'GALAXY'  b'STARFORMING' -1.079854 -0.873216 -1.527660 -3.115626
# 48  ...  b'GALAXY'  b'STARFORMING' -0.797622 -0.984128 -0.956714 -3.537979
# 49  ...  b'GALAXY'  b'STARFORMING' -0.385603 -0.097052 -1.065971 -2.842807
# 50  ...  b'GALAXY'  b'STARFORMING' -0.909937 -0.566826 -1.263300 -2.880370
# 51  ...  b'GALAXY'  b'STARFORMING' -1.484263 -0.862622 -1.498210 -3.321264
# 52  ...  b'GALAXY'    b'STARBURST' -1.348590 -0.795386 -1.185779 -3.785177
# 53  ...  b'GALAXY'  b'STARFORMING' -1.573191 -0.531822 -1.527646 -3.898929
# 54  ...  b'GALAXY'  b'STARFORMING'  0.062736 -0.565643 -0.529997 -2.043477
#
#     Infrarroja  Seyfert LINER  PreEtiquetaSII
# 45           1        0     0      Infrarroja
# 46           1        0     0      Infrarroja
# 47           1        0     0      Infrarroja
# 48           1        0     0      Infrarroja
# 49           1        0     0      Infrarroja
# 50           1        0     0      Infrarroja
# 51           1        0     0      Infrarroja
# 52           1        0     0      Infrarroja
# 53           1        0     0      Infrarroja
# 54           1        0     0      Infrarroja
#
# [10 rows x 22 columns]

# %% [markdown]
# ### 1.3.4 Graficas de SII Deductiva.

# %%
import matplotlib.pyplot as plt

# Crear la figura y los ejes
fig, ax = plt.subplots()

# Filtrar los datos por etiqueta
datos_infrarroja = df[df["PreEtiquetaSII"] == "Infrarroja"]
datos_liner = df[df["PreEtiquetaSII"] == "LINER"]
datos_seyfert = df[df["PreEtiquetaSII"] == "Seyfert"]

# Graficar los puntos con colores según la etiqueta
ax.scatter(datos_infrarroja["Ejex_SH"], datos_infrarroja["Ejey_OHB"], marker="+", color="olivedrab", label="Infrarroja")
ax.scatter(datos_seyfert["Ejex_SH"], datos_seyfert["Ejey_OHB"], marker="+", color="yellowgreen", label="Seyfert")
ax.scatter(datos_liner["Ejex_SH"], datos_liner["Ejey_OHB"], marker="+", color="gold", label="LINER")

# Configurar los límites de los ejes
ax.set_xlim([-4, 2])
ax.set_ylim([-4, 4])

# Agregar etiquetas y título
plt.xlabel("Ejex_SH")
plt.ylabel("Ejey_OHB")
plt.title("Gráfica con colores según PreEtiqueta")
plt.legend()

# %%
df2=df
