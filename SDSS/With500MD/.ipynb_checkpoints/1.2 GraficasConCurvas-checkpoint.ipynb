# %% [markdown]
# Objetivo:
# 1. Realizar descarga de datos desde astroquery: objid, ra, dec y los flujos de emisión del BPT clásico, con 500.000 galaxias.
# 2. Realizar BPT clásico: Razones de líneas y gráficas primeras.
# 3. Dibujar líneas de separación de fuente de ionización según ecuaciones de: **The Host Galaxies and Classification of Active Galactic Nuclei - 2006**
# 4. Con Z < 0.8

# %%
import numpy as np
import pandas as pd
import time
from datetime import date
import warnings
warnings.filterwarnings 
import astropy.units as u
from astropy.table import Table
from astroquery.sdss import SDSS
import matplotlib.pyplot as plt

# %%
query = """SELECT TOP 500000
    s.specobjid, s.ra, s.dec, s.z, g.h_alpha_flux, g.h_beta_flux,
    g.oiii_5007_flux, g.nii_6548_flux, g.nii_6584_flux,
    g.sii_6717_flux, g.sii_6731_flux, g.oi_6300_flux, s.class, s.subclass

    FROM SpecObjAll AS s
    JOIN galSpecExtra AS ID ON ID.specObjID = s.specObjID
    JOIN galSpecLine AS g ON g.specObjID = s.specObjID


    WHERE subclass IN ('STARFORMING', 'STARBURST', 'AGN', 'BROADLINE')
    AND NOT h_alpha_flux <='0' AND NOT h_beta_flux <='0'
    AND NOT oiii_5007_flux <='0' AND NOT nii_6548_flux <='0'
    AND NOT nii_6584_flux <='0' AND NOT sii_6717_flux <='0' 
    AND NOT sii_6731_flux <='0' AND NOT oi_6300_flux <='0'
    AND z < 0.8

    ORDER BY specobjid ASC"""

data = SDSS.query_sql(query)
data
# Out:
# C:\ProgramData\Anaconda33\lib\site-packages\astroquery\sdss\core.py:874: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
#   arr = np.atleast_1d(np.genfromtxt(io.BytesIO(response.content),
# <Table length=329650>
#      specobjid          ra        dec     ... oi_6300_flux class    subclass
#        int64         float64    float64   ...   float64    bytes6   bytes11
# ------------------- --------- ----------- ... ------------ ------ -----------
#  299489677444933632 146.71421  -1.0413043 ...     18.59493 GALAXY STARFORMING
#  299490502078654464 146.62857 -0.76513683 ...     8.490424 GALAXY STARFORMING
#  299491051364706304  146.9639 -0.54500256 ...     4.319232 GALAXY   STARBURST
#  299491051834468352 146.63167 -0.98827781 ...     6.269853 GALAXY STARFORMING
#  299492700632147968 146.59272 -0.76025604 ...     7.211103 GALAXY STARFORMING
#  299492701101910016  146.9639 -0.54500256 ...      2.18458 GALAXY STARFORMING
#  299493250857723904 146.94999 -0.59220225 ...     7.237874 GALAXY STARFORMING
#  299493525265868800 146.94999 -0.59220225 ...      7.67483 GALAXY STARFORMING
#  299493800143775744 146.63167 -0.98827781 ...     2.733802 GALAXY STARFORMING
#  299494075021682688 146.62857 -0.76513683 ...     5.045829 GALAXY STARFORMING
#                 ...       ...         ... ...          ...    ...         ...
# 3348582805520017408  260.6556   31.654756 ...     5.111954 GALAXY STARFORMING
# 3348583080397924352 260.90071   31.532274 ...     13.83892 GALAXY   STARBURST
# 3348583630153738240 260.90263   31.134108 ...      8.48487 GALAXY STARFORMING
# 3348584179909552128 260.91501   31.221169 ...     5.380894 GALAXY STARFORMING
# 3348590776979318784 260.67041   31.917043 ...     10.50863 GALAXY   STARBURST
# 3348592976002574336  261.1035   31.590881 ...     3.046409 GALAXY STARFORMING
# 3348593250880481280 261.13056   31.473702 ...     5.718228 GALAXY STARFORMING
# 3348596274537457664 261.24627   31.260667 ...      11.8454 GALAXY   STARBURST
# 3348598748438620160 260.92678   31.854907 ...     22.41476    QSO   BROADLINE
# 3348599023316527104 260.71475   32.361811 ...     4.500745 GALAXY STARFORMING

# %% [markdown]
# ## Razones

# %%
ejey_OHb=np.log((data['oiii_5007_flux'])/(data['h_beta_flux']))

ejex_NH=np.log((data['nii_6548_flux']+data['nii_6584_flux'])/data['h_alpha_flux'])
ejex_SH=np.log((data['sii_6717_flux']+data['sii_6731_flux'])/data['h_alpha_flux'])
ejex_OH=np.log((data['oi_6300_flux'])/(data['h_alpha_flux']))

# %% [markdown]
# ## Gráficas

# %%
fig = plt.figure()
ax = fig.add_subplot()
ax.scatter(ejex_NH, ejey_OHb, marker=".", color="purple")
# Cuadrado:
ax.set_xlim([-4, 2])
ax.set_ylim([-4, 4])
plt.title('BPT Clásico, Gráfico a')
plt.ylabel('log [O III]/ Hβ')
plt.xlabel('log [NII] /Hα')

# Kewley
x1 = np.linspace(-10,0.4)  
y1 = 1.19 + (0.61/(x1-0.47))
plt.plot(x1, y1, '-', color='red', lw=2, label= 'Kewley') 


# Kauffmann
x2 = np.linspace(-10,0)
y2 = 1.3 + (0.61/(x2-0.05))
plt.plot(x2, y2, '--', color='blue', lw=2, label='Kauffman')


# Seyfert-LINER
x3 = np.linspace(-0.2,5)
y3 = 1.01 * x3 +0.48
plt.plot(x3, y3, '-.', color='green', lw=2, label='Seyfert-LINER')

plt.legend()
# Out:
# C:\ProgramData\Anaconda33\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# Debajo de la línea azul: HII - Galaxias formadoras de estrellas.
# Entre línea azul y roja: Galaxias compuestas.
# Arriba de la línea roja: AGNs.

# %%
fig = plt.figure()
ax1 = fig.add_subplot()
ax1.scatter(ejex_SH,ejey_OHb, marker="+", color="blue")
# Cuadrado:
ax1.set_xlim([-10, 10])
ax1.set_ylim([-10, 10])
plt.title('BPT Clásico, Gráfico b')
plt.ylabel('log [O III]/ Hβ')
plt.xlabel('log [SII] /Hα')

# Kewley
x1 = np.linspace(-10,0.3) 
y1 = 1.30 + (0.72/(x1-0.32))
plt.plot(x1, y1, '-' , color='red', lw=2, label= 'Kewley') 


# Seyfert-LINER
x2 = np.linspace(-0.32,4.0)
y2 = 0.76 + (1.89*x2)
plt.plot(x2, y2, '-.', color='green', lw=2, label='Seyfert-LINER')

plt.legend()

# %% [markdown]
# Debajo de la línea roja: Región infrarroja.
# Encima de la línea Seyfert-LINER: Seyfert
# Debajo de la línea Seyfert-LINER: LINER

# %%
fig = plt.figure()
ax2 = fig.add_subplot() 
ax2.scatter(ejex_OH, ejey_OHb, marker="*", color="cyan")
# Cuadrado:
ax2.set_xlim([-15, 10])
ax2.set_ylim([-10, 10])
plt.title('BPT Clásico, Gráfico c')
plt.ylabel('log [O III]/ Hβ')
plt.xlabel('log [OI] /Hα')

# Kewley
x1 = np.linspace(-15, -0.6) 
y1 = 1.33 + (0.73/(x1+0.59))
plt.plot(x1, y1, '-', color='red', lw=2, label= 'Kewley') 


# Seyfert-LINER
x2 = np.linspace(-1.15, 8)
y2 = 1.3 + (1.18*x2) 
plt.plot(x2, y2, '-.', color='green', lw=2, label='Seyfert-LINER')


# plt.legend()

# %% [markdown]
# ## Próximos códigos:
#
#     2.1 ML No Supervisado: k-means centroides.

# %% [markdown]
# ## Resultado de lo anterior:
#
#     El anterior se llamó: 2.1 Kmeans
